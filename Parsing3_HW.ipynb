# %% [markdown]
# <a href="https://colab.research.google.com/github/Hanna413/Parsing_GB/blob/Lesson3_BeautifulSoup/Parsing3_HW.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from bs4 import BeautifulSoup as bs
import requests
from time import sleep

# %%
def page_for_parsing(vacancy_name, num_page):

    url = 'https://hh.ru/search/vacancy'

    headers = {
            'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/110.0.0.0 Safari/537.36',
            }

    params = {'text': vacancy_name, 'page': num_page}

    return requests.get(url=url, headers=headers, params=params)

# %%
def clean_salary(vacancy_salary_text, min_salary=None, max_salary=None, currency_salary=None):
  list_salary = vacancy_salary_text.replace('\u202f', '').split()
  for i in range(len(list_salary) - 1):
    if list_salary[i] == 'от':
      min_salary = int(list_salary[i + 1])
    elif list_salary[i] == 'до':
      max_salary = int(list_salary[i + 1])
    elif list_salary[i] == '–':
      min_salary = int(list_salary[i - 1])
      max_salary = int(list_salary[i + 1])
  currency_salary = list_salary[-1]

  return min_salary, max_salary, currency_salary

# %%
vacancy_list = []
for page in range(0, 40):
  response = page_for_parsing('python', page)
  
  #print(response.url)
  soup = bs(response.content, 'html.parser')
  vacancies = soup.find_all('div',{'class': 'vacancy-serp-item__layout'})
  for vacancy in vacancies:
    vacancy_name = vacancy.find('a').text

    vacancy_salary = vacancy.find('span', {'class', 'bloko-header-section-3'})
    if vacancy_salary:
      vacancy_salary = vacancy_salary.text
      min_salary, max_salary, currency_salary = clean_salary(vacancy_salary)
    else:
      vacancy_salary = 'З/П не указана'
      min_salary, max_salary, currency_salary = None, None, None

    vacancy_link = vacancy.find('a')['href']

    vacancy_dict = {
        'name': vacancy_name,
        'salary' : vacancy_salary,
        'min_salary': min_salary,
        'max_salary': max_salary,
        'currency_salary': currency_salary,
        'link' : vacancy_link,
    }

    vacancy_list.append(vacancy_dict)

  i += 1
  sleep(0.1)

# %%
vacancy_list
# Out:
# [{'name': 'Ведущий инженер по тестированию (python)',
#   'salary': 'З/П не указана',
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'link': 'https://hh.ru/vacancy/73199414?from=vacancy_search_list&query=python'},
#  {'name': 'Аналитик данных / Data Analyst',
#   'salary': 'З/П не указана',
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'link': 'https://hh.ru/vacancy/69166398?from=vacancy_search_list&query=python'},
#  {'name': 'Аналитик данных / Data Analyst',
#   'salary': 'З/П не указана',
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'link': 'https://hh.ru/vacancy/76869170?from=vacancy_search_list&query=python'},
#  {'name': 'Преподаватель Backend направления',
#   'salary': '6\u202f000\u202f000 – 10\u202f000\u202f000 сум',
#   'min_salary': 6000000,
#   'max_salary': 10000000,
#   'currency_salary': 'сум',
#   'link': 'https://hh.ru/vacancy/77349432?from=vacancy_search_list&query=python'},
#  {'name': 'Младший инженер по тестированию (QA performance engineer Junior)',
#   'salary': 'З/П не указана',
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'link': 'https://hh.ru/vacancy/76087775?from=vacancy_search_list&query=python'},
#  {'name': 'Специалист по углубленной аналитике данных (Data scientist)',
#   'salary': 'З/П не указана',
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'link': 'https://hh.ru/vacancy/72920605?from=vacancy_search_list&query=python'},
#  {'name': 'SQL разработчик',
#   'salary': 'З/П не указана',
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'link': 'https://hh.ru/vacancy/77286859?from=vacancy_search_list&query=python'},
#  {'name': 'Разработчик Python',
#   'salary': '200\u202f000 – 250\u202f000 руб.',
#   'min_salary': 200000,
#   'max_salary': 250000,
#   'currency_salary': 'руб.',
#   'link': 'https://hh.ru/vacancy/77091466?from=vacancy_search_list&query=python'},
#  {'name': 'Программист Python Junior',
#   'salary': 'З/П не указана',
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'link': 'https://hh.ru/vacancy/77146976?from=vacancy_search_list&query=python'},
#  {'name': 'Python-разработчик (Django, DRF)',
#   'salary': '60\u202f000 – 220\u202f000 руб.',
#   'min_salary': 60000,
#   'max_salary': 220000,
#   'currency_salary': 'руб.',
#   'link': 'https://hh.ru/vacancy/70705466?from=vacancy_search_list&query=python'},
#  {'name': 'Разработчик Python',
#   'salary': '200\u202f000 – 250\u202f000 руб.',
#   'min_salary': 200000,
#   'max_salary': 250000,
#   'currency_salary': 'руб.',
#   'link': 'https://hh.ru/vacancy/77091465?from=vacancy_search_list&query=python'},
#  {'name': 'Разработчик C# / Python',
#   'salary': '300\u202f000 – 500\u202f000 руб.',
#   'min_salary': 300000,
#   'max_salary': 500000,
#   'currency_salary': 'руб.',
#   'link': 'https://hh.ru/vacancy/71147348?from=vacancy_search_list&query=python'},
#  {'name': 'Python Backend Developer / WEB - разработчик',
#   'salary': '300\u202f000 – 450\u202f000 руб.',
#   'min_salary': 300000,
#   'max_salary': 450000,
#   'currency_salary': 'руб.',
#   'link': 'https://hh.ru/vacancy/72216524?from=vacancy_search_list&query=python'},
#  {'name': 'Ведущий Python разработчик (удаленка)',
#   'salary': 'до 8\u202f000 USD',
#   'min_salary': None,
#   'max_salary': 8000,
#   'currency_salary': 'USD',
#   'link': 'https://hh.ru/vacancy/76832091?from=vacancy_search_list&query=python'},
#  {'name': 'Backend (Python) инженер',
#   'salary': '800\u202f000 – 1\u202f300\u202f000 KZT',
#   'min_salary': 800000,
#   'max_salary': 1300000,
#   'currency_salary': 'KZT',
#   'link': 'https://hh.ru/vacancy/77382317?from=vacancy_search_list&query=python'},
#  {'name': 'Junior+ Python Backend Developer',
#   'salary': 'до 120\u202f000 руб.',
#   'min_salary': None,
#   'max_salary': 120000,
#   'currency_salary': 'руб.',
#   'link': 'https://hh.ru/vacancy/77372405?from=vacancy_search_list&query=python'},
#  {'name': 'Backend developer (Python)',
#   'salary': '60\u202f000 – 150\u202f000 руб.',
#   'min_salary': 60000,
#   'max_salary': 150000,
#   'currency_salary': 'руб.',
#   'link': 'https://hh.ru/vacancy/76716478?from=vacancy_search_list&query=python'},
#  {'name': 'Junior+ программист-разработчик на Python',
#   'salary': 'до 150\u202f000 руб.',
#   'min_salary': None,
#   'max_salary': 150000,
#   'currency_salary': 'руб.',
#   'link': 'https://hh.ru/vacancy/77357729?from=vacancy_search_list&query=python'},
#  {'name': 'Python разработчик',
#   'salary': 'от 25\u202f000 руб.',
#   'min_salary': 25000,
#   'max_salary': None,
#   'currency_salary': 'руб.',
#   'link': 'https://hh.ru/vacancy/76818478?from=vacancy_search_list&query=python'},
#  {'name': 'Python Developer по работе с ChatGPT (генеративным AI)',
#   'salary': 'З/П не указана',
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'link': 'https://hh.ru/vacancy/77144612?from=vacancy_search_list&query=python'},
#  {'name': 'Программист Python (Django)',
#   'salary': '160\u202f000 – 180\u202f000 руб.',
#   'min_salary': 160000,
#   'max_salary': 180000,
#   'currency_salary': 'руб.',
#   'link': 'https://hh.ru/vacancy/76826004?from=vacancy_search_list&query=python'},
#  {'name': 'Ведущий Python Backend разработчик',
#   'salary': 'до 5\u202f000 USD',
#   'min_salary': None,
#   'max_salary': 5000,
#   'currency_salary': 'USD',
#   'link': 'https://hh.ru/vacancy/77304894?from=vacancy_search_list&query=python'},
#  {'name': 'Начинающий программист BI (sql/python/js)',
#   'salary': '50\u202f000 – 70\u202f000 руб.',
#   'min_salary': 50000,
#   'max_salary': 70000,
#   'currency_salary': 'руб.',
#   'link': 'https://hh.ru/vacancy/76569529?from=vacancy_search_list&query=python'},
#  {'name': 'Backend-разработчик / Python developer',
#   'salary': '100\u202f000 – 200\u202f000 руб.',
#   'min_salary': 100000,
#   'max_salary': 200000,
#   'currency_salary': 'руб.',
#   'link': 'https://hh.ru/vacancy/76358462?from=vacancy_search_list&query=python'},
#  {'name': 'Data Scientist middle+/Senior',
#   'salary': '250\u202f000 – 350\u202f000 руб.',
#   'min_salary': 250000,
#   'max_salary': 350000,
#   'currency_salary': 'руб.',
#   'link': 'https://hh.ru/vacancy/77208642?from=vacancy_search_list&query=python'},
#  {'name': 'Аналитик данных / Data Analyst',
#   'salary': '160\u202f000 – 200\u202f000 руб.',
#   'min_salary': 160000,
#   'max_salary': 200000,
#   'currency_salary': 'руб.',
#   'link': 'https://hh.ru/vacancy/77334669?from=vacancy_search_list&query=python'},
#  {'name': 'Python-developer',
#   'salary': '100\u202f000 – 215\u202f000 руб.',
#   'min_salary': 100000,
#   'max_salary': 215000,
#   'currency_salary': 'руб.',
#   'link': 'https://hh.ru/vacancy/67635148?from=vacancy_search_list&query=python'},
#  {'name': 'Data Analyst (Remote)',
#   'salary': '3\u202f000 – 4\u202f000 USD',
#   'min_salary': 3000,
#   'max_salary': 4000,
#   'currency_salary': 'USD',
#   'link': 'https://hh.ru/vacancy/74736549?from=vacancy_search_list&query=python'},
#  {'name': 'Удаленный стажер-аналитик (графовые базы данных)',
#   'salary': 'З/П не указана',
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'link': 'https://hh.ru/vacancy/77347089?from=vacancy_search_list&query=python'},
#  {'name': 'Backend разработчик Python',
#   'salary': '35\u202f000 – 50\u202f000 руб.',
#   'min_salary': 35000,
#   'max_salary': 50000,
#   'currency_salary': 'руб.',
#   'link': 'https://hh.ru/vacancy/77336288?from=vacancy_search_list&query=python'},
#  {'name': 'Data Scientist',
#   'salary': '160\u202f000 – 200\u202f000 руб.',
#   'min_salary': 160000,
#   'max_salary': 200000,
#   'currency_salary': 'руб.',
#   'link': 'https://hh.ru/vacancy/76925483?from=vacancy_search_list&query=python'},
#  {'name': 'Разработчик бэкэнд (Python)',
#   'salary': '150\u202f000 – 180\u202f000 руб.',
#   'min_salary': 150000,
#   'max_salary': 180000,
#   'currency_salary': 'руб.',
#   'link': 'https://hh.ru/vacancy/76712573?from=vacancy_search_list&query=python'},
#  {'name': 'Python Backend Developer / Data Engineer',
#   'salary': 'до 250\u202f000 руб.',
#   'min_salary': None,
#   'max_salary': 250000,
#   'currency_salary': 'руб.',
#   'link': 'https://hh.ru/vacancy/77121880?from=vacancy_search_list&query=python'},
#  {'name': 'Middle Python developer (Казань)',
#   'salary': 'от 160\u202f000 руб.',
#   'min_salary': 160000,
#   'max_salary': None,
#   'currency_salary': 'руб.',
#   'link': 'https://hh.ru/vacancy/76115939?from=vacancy_search_list&query=python'},
#  {'name': 'Стажер',
#   'salary': 'до 80\u202f000 руб.',
#   'min_salary': None,
#   'max_salary': 80000,
#   'currency_salary': 'руб.',
#   'link': 'https://hh.ru/vacancy/76809922?from=vacancy_search_list&query=python'},
#  {'name': 'АККРЕДИТОВАННАЯ КОМПАНИЯ Data Scientist / Python разработчик',
#   'salary': 'З/П не указана',
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'link': 'https://hh.ru/vacancy/48411370?from=vacancy_search_list&query=python'},
#  {'name': 'Data Engineer',
#   'salary': '200\u202f000 – 280\u202f000 руб.',
#   'min_salary': 200000,
#   'max_salary': 280000,
#   'currency_salary': 'руб.',
#   'link': 'https://hh.ru/vacancy/77015802?from=vacancy_search_list&query=python'},
#  {'name': 'Python (Django) Backend developer',
#   'salary': 'до 280\u202f000 руб.',
#   'min_salary': None,
#   'max_salary': 280000,
#   'currency_salary': 'руб.',
#   'link': 'https://hh.ru/vacancy/76768230?from=vacancy_search_list&query=python'},
#  {'name': 'Python / JavaScript разработчик веб-приложений (Fullstack)',
#   'salary': '80\u202f000 – 120\u202f000 руб.',
#   'min_salary': 80000,
#   'max_salary': 120000,
#   'currency_salary': 'руб.',
#   'link': 'https://hh.ru/vacancy/77351026?from=vacancy_search_list&query=python'},
#  {'name': 'Artificial Intelligence / Machine Learning Engineer',
#   'salary': 'З/П не указана',
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'link': 'https://hh.ru/vacancy/77351701?from=vacancy_search_list&query=python'},
#  {'name': 'Python-разработчик в R&D отдел',
#   'salary': '100\u202f000 – 150\u202f000 руб.',
#   'min_salary': 100000,
#   'max_salary': 150000,
#   'currency_salary': 'руб.',
#   'link': 'https://hh.ru/vacancy/49299311?from=vacancy_search_list&query=python'},
#  {'name': 'Разработчик Python',
#   'salary': '30\u202f000 – 80\u202f000 руб.',
#   'min_salary': 30000,
#   'max_salary': 80000,
#   'currency_salary': 'руб.',
#   'link': 'https://hh.ru/vacancy/47668037?from=vacancy_search_list&query=python'},
#  {'name': 'Fullstack Python техлид (Облачные квантовые вычисления)',
#   'salary': '250\u202f000 – 450\u202f000 руб.',
#   'min_salary': 250000,
#   'max_salary': 450000,
#   'currency_salary': 'руб.',
#   'link': 'https://hh.ru/vacancy/76924335?from=vacancy_search_list&query=python'},
#  {'name': 'Backend Developer Python',
#   'salary': 'З/П не указана',
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'link': 'https://hh.ru/vacancy/77365703?from=vacancy_search_list&query=python'},
#  {'name': 'Программист-стажер GO / Go Intern (Telecom)',
#   'salary': 'З/П не указана',
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'link': 'https://hh.ru/vacancy/77339852?from=vacancy_search_list&query=python'},
#  {'name': 'Python developer',
#   'salary': 'З/П не указана',
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'link': 'https://hh.ru/vacancy/77339906?from=vacancy_search_list&query=python'},
#  {'name': 'Python Developer',
#   'salary': 'З/П не указана',
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'link': 'https://hh.ru/vacancy/76498335?from=vacancy_search_list&query=python'},
#  {'name': 'Программист Python+Django',
#   'salary': 'от 25\u202f000 руб.',
#   'min_salary': 25000,
#   'max_salary': None,
#   'currency_salary': 'руб.',
#   'link': 'https://hh.ru/vacancy/77232367?from=vacancy_search_list&query=python'},
#  {'name': 'Программист Python',
#   'salary': 'З/П не указана',
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'link': 'https://hh.ru/vacancy/77218092?from=vacancy_search_list&query=python'},
#  {'name': 'Преподаватель Python',
#   'salary': 'от 125\u202f000 руб.',
#   'min_salary': 125000,
#   'max_salary': None,
#   'currency_salary': 'руб.',
#   'link': 'https://hh.ru/vacancy/77083925?from=vacancy_search_list&query=python'},
#  {'name': 'Python developer',
#   'salary': 'З/П не указана',
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'link': 'https://hh.ru/vacancy/75574711?from=vacancy_search_list&query=python'},
#  {'name': 'Data/Product Analyst',
#   'salary': 'до 330\u202f000 руб.',
#   'min_salary': None,
#   'max_salary': 330000,
#   'currency_salary': 'руб.',
#   'link': 'https://hh.ru/vacancy/77206133?from=vacancy_search_list&query=python'},
#  {'name': 'Разработчик бэкенда на Python в Вертикали',
#   'salary': 'З/П не указана',
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'link': 'https://hh.ru/vacancy/76831393?from=vacancy_search_list&query=python'},
#  {'name': 'Разработчик Python',
#   'salary': 'от 120\u202f000 руб.',
#   'min_salary': 120000,
#   'max_salary': None,
#   'currency_salary': 'руб.',
#   'link': 'https://hh.ru/vacancy/76076341?from=vacancy_search_list&query=python'},
#  {'name': 'Ментор на курс Python',
#   'salary': 'З/П не указана',
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'link': 'https://hh.ru/vacancy/77259417?from=vacancy_search_list&query=python'},
#  {'name': 'Junior/Middle Backend-разработчик на Ruby',
#   'salary': '110\u202f000 – 150\u202f000 руб.',
#   'min_salary': 110000,
#   'max_salary': 150000,
#   'currency_salary': 'руб.',
#   'link': 'https://hh.ru/vacancy/76964796?from=vacancy_search_list&query=python'},
#  {'name': 'Разработчик Python',
#   'salary': 'от 150\u202f000 руб.',
#   'min_salary': 150000,
#   'max_salary': None,
#   'currency_salary': 'руб.',
#   'link': 'https://hh.ru/vacancy/76433537?from=vacancy_search_list&query=python'},
#  {'name': 'Аналитик данных / Data Analyst',
#   'salary': '80\u202f000 – 120\u202f000 руб.',
#   'min_salary': 80000,
#   'max_salary': 120000,
#   'currency_salary': 'руб.',
#   'link': 'https://hh.ru/vacancy/77024983?from=vacancy_search_list&query=python'},
#  {'name': 'AI / ML Specialist',
#   'salary': 'З/П не указана',
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'link': 'https://hh.ru/vacancy/77185485?from=vacancy_search_list&query=python'},
#  {'name': 'Python Data Engineer (junior)',
#   'salary': 'З/П не указана',
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'link': 'https://hh.ru/vacancy/76141435?from=vacancy_search_list&query=python'},
#  {'name': 'Python developer (remote)',
#   'salary': 'от 1\u202f000 USD',
#   'min_salary': 1000,
#   'max_salary': None,
#   'currency_salary': 'USD',
#   'link': 'https://hh.ru/vacancy/77245811?from=vacancy_search_list&query=python'},
#  {'name': 'Разработчик Python',
#   'salary': 'от 200\u202f000 руб.',
#   'min_salary': 200000,
#   'max_salary': None,
#   'currency_salary': 'руб.',
#   'link': 'https://hh.ru/vacancy/77089579?from=vacancy_search_list&query=python'},
#  {'name': 'Python Web Developer',
#   'salary': 'З/П не указана',
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'link': 'https://hh.ru/vacancy/75771778?from=vacancy_search_list&query=python'},
#  {'name': 'Artificial Intelligence / Machine Learning Engineer',
#   'salary': 'З/П не указана',
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'link': 'https://hh.ru/vacancy/77351702?from=vacancy_search_list&query=python'},
#  {'name': 'С++ Developer (Python)',
#   'salary': 'от 150\u202f000 руб.',
#   'min_salary': 150000,
#   'max_salary': None,
#   'currency_salary': 'руб.',
#   'link': 'https://hh.ru/vacancy/73030684?from=vacancy_search_list&query=python'},
#  {'name': 'Backend программист (Python)',
#   'salary': 'от 120\u202f000 руб.',
#   'min_salary': 120000,
#   'max_salary': None,
#   'currency_salary': 'руб.',
#   'link': 'https://hh.ru/vacancy/77147428?from=vacancy_search_list&query=python'},
#  {'name': 'Middle Python developer',
#   'salary': '120\u202f000 – 200\u202f000 руб.',
#   'min_salary': 120000,
#   'max_salary': 200000,
#   'currency_salary': 'руб.',
#   'link': 'https://hh.ru/vacancy/76595028?from=vacancy_search_list&query=python'},
#  {'name': 'Middle Python-разработчик',
#   'salary': '140\u202f000 – 250\u202f000 руб.',
#   'min_salary': 140000,
#   'max_salary': 250000,
#   'currency_salary': 'руб.',
#   'link': 'https://hh.ru/vacancy/75679088?from=vacancy_search_list&query=python'},
#  {'name': 'Разработчик Python и SQL',
#   'salary': 'от 60\u202f000 руб.',
#   'min_salary': 60000,
#   'max_salary': None,
#   'currency_salary': 'руб.',
#   'link': 'https://hh.ru/vacancy/76425036?from=vacancy_search_list&query=python'},
#  {'name': 'Python-разработчик систем сбора',
#   'salary': '100\u202f000 – 150\u202f000 руб.',
#   'min_salary': 100000,
#   'max_salary': 150000,
#   'currency_salary': 'руб.',
#   'link': 'https://hh.ru/vacancy/72687495?from=vacancy_search_list&query=python'},
#  {'name': 'Middle Python/Go developer',
#   'salary': 'от 150\u202f000 руб.',
#   'min_salary': 150000,
#   'max_salary': None,
#   'currency_salary': 'руб.',
#   'link': 'https://hh.ru/vacancy/77230563?from=vacancy_search_list&query=python'},
#  {'name': 'Стажер-аналитик',
#   'salary': 'З/П не указана',
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'link': 'https://hh.ru/vacancy/77306960?from=vacancy_search_list&query=python'},
#  {'name': 'Программист-разработчик',
#   'salary': 'З/П не указана',
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'link': 'https://hh.ru/vacancy/76762046?from=vacancy_search_list&query=python'},
#  {'name': 'Full-stack Python/Django-разработчик',
#   'salary': 'до 200\u202f000 руб.',
#   'min_salary': None,
#   'max_salary': 200000,
#   'currency_salary': 'руб.',
#   'link': 'https://hh.ru/vacancy/76549392?from=vacancy_search_list&query=python'},
#  {'name': 'Аналитик данных (Data Analist)',
#   'salary': 'З/П не указана',
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'link': 'https://hh.ru/vacancy/76584671?from=vacancy_search_list&query=python'},
#  {'name': 'Python Developer',
#   'salary': 'З/П не указана',
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'link': 'https://hh.ru/vacancy/76843829?from=vacancy_search_list&query=python'},
#  {'name': 'Data Scientist CVM',
#   'salary': 'З/П не указана',
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'link': 'https://hh.ru/vacancy/77366229?from=vacancy_search_list&query=python'},
#  {'name': 'Senior Python Developer (Беспилотные автомобили)',
#   'salary': 'З/П не указана',
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'link': 'https://hh.ru/vacancy/76985818?from=vacancy_search_list&query=python'},
#  {'name': 'Преподаватель Python',
#   'salary': 'от 125\u202f000 руб.',
#   'min_salary': 125000,
#   'max_salary': None,
#   'currency_salary': 'руб.',
#   'link': 'https://hh.ru/vacancy/77083926?from=vacancy_search_list&query=python'},
#  {'name': 'Backend-разработчик Python/Django',
#   'salary': 'З/П не указана',
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'link': 'https://hh.ru/vacancy/75850366?from=vacancy_search_list&query=python'},
#  {'name': 'Python / Go Разработчик',
#   'salary': 'З/П не указана',
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'link': 'https://hh.ru/vacancy/74089202?from=vacancy_search_list&query=python'},
#  {'name': 'Программист Python',
#   'salary': 'З/П не указана',
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'link': 'https://hh.ru/vacancy/75704098?from=vacancy_search_list&query=python'},
#  {'name': 'DevOps инженер',
#   'salary': '100\u202f000 – 120\u202f000 руб.',
#   'min_salary': 100000,
#   'max_salary': 120000,
#   'currency_salary': 'руб.',
#   'link': 'https://hh.ru/vacancy/76587347?from=vacancy_search_list&query=python'},
#  {'name': 'Lead Backend Developer (python)',
#   'salary': 'от 200\u202f000 руб.',
#   'min_salary': 200000,
#   'max_salary': None,
#   'currency_salary': 'руб.',
#   'link': 'https://hh.ru/vacancy/76971118?from=vacancy_search_list&query=python'},
#  {'name': 'Data analyst / Аналитик данных',
#   'salary': 'от 90\u202f000 руб.',
#   'min_salary': 90000,
#   'max_salary': None,
#   'currency_salary': 'руб.',
#   'link': 'https://hh.ru/vacancy/76690668?from=vacancy_search_list&query=python'},
#  {'name': 'Senior Python developer (Django)',
#   'salary': 'до 450\u202f000 руб.',
#   'min_salary': None,
#   'max_salary': 450000,
#   'currency_salary': 'руб.',
#   'link': 'https://hh.ru/vacancy/76821520?from=vacancy_search_list&query=python'},
#  {'name': 'Инженер данных ClickHouse',
#   'salary': '120\u202f000 – 200\u202f000 руб.',
#   'min_salary': 120000,
#   'max_salary': 200000,
#   'currency_salary': 'руб.',
#   'link': 'https://hh.ru/vacancy/77225799?from=vacancy_search_list&query=python'},
#  {'name': 'Senior Python developer (Django)',
#   'salary': 'до 450\u202f000 руб.',
#   'min_salary': None,
#   'max_salary': 450000,
#   'currency_salary': 'руб.',
#   'link': 'https://hh.ru/vacancy/76821519?from=vacancy_search_list&query=python'},
#  {'name': 'Разработчик Python',
#   'salary': '80\u202f000 – 120\u202f000 руб.',
#   'min_salary': 80000,
#   'max_salary': 120000,
#   'currency_salary': 'руб.',
#   'link': 'https://hh.ru/vacancy/77038104?from=vacancy_search_list&query=python'},
#  {'name': 'Инженер-программист Python (автоматизация испытательных стендов)',
#   'salary': 'З/П не указана',
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'link': 'https://hh.ru/vacancy/76924233?from=vacancy_search_list&query=python'},
#  {'name': 'Deep Learning инженер',
#   'salary': 'З/П не указана',
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'link': 'https://hh.ru/vacancy/76752874?from=vacancy_search_list&query=python'},
#  {'name': 'Python developer',
#   'salary': '150\u202f000 – 250\u202f000 руб.',
#   'min_salary': 150000,
#   'max_salary': 250000,
#   'currency_salary': 'руб.',
#   'link': 'https://hh.ru/vacancy/46229759?from=vacancy_search_list&query=python'},
#  {'name': 'Middle / Middle+ Python (Django) developer',
#   'salary': 'З/П не указана',
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'link': 'https://hh.ru/vacancy/76541749?from=vacancy_search_list&query=python'},
#  {'name': 'Программист Python - FastAPI',
#   'salary': 'от 180\u202f000 руб.',
#   'min_salary': 180000,
#   'max_salary': None,
#   'currency_salary': 'руб.',
#   'link': 'https://hh.ru/vacancy/77096692?from=vacancy_search_list&query=python'},
#  {'name': 'Программист Python',
#   'salary': 'З/П не указана',
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'link': 'https://hh.ru/vacancy/77065085?from=vacancy_search_list&query=python'},
#  {'name': 'Python developer',
#   'salary': 'З/П не указана',
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'link': 'https://hh.ru/vacancy/76544211?from=vacancy_search_list&query=python'},
#  {'name': 'Python developer (middle/senior) удаленно',
#   'salary': 'З/П не указана',
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'link': 'https://hh.ru/vacancy/77321723?from=vacancy_search_list&query=python'},
#  {'name': 'Data Scientist/python-разработчик',
#   'salary': 'З/П не указана',
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'link': 'https://hh.ru/vacancy/77107666?from=vacancy_search_list&query=python'},
#  {'name': 'Программист Python - FastAPI',
#   'salary': 'от 180\u202f000 руб.',
#   'min_salary': 180000,
#   'max_salary': None,
#   'currency_salary': 'руб.',
#   'link': 'https://hh.ru/vacancy/77096615?from=vacancy_search_list&query=python'},
#  {'name': 'Python senior developer (разработчик)',
#   'salary': 'от 250\u202f000 руб.',
#   'min_salary': 250000,
#   'max_salary': None,
#   'currency_salary': 'руб.',
#   'link': 'https://hh.ru/vacancy/76840139?from=vacancy_search_list&query=python'},
#  {'name': 'Python Back-end Разработчик / Python Back-end Developer',
#   'salary': 'З/П не указана',
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'link': 'https://hh.ru/vacancy/46823861?from=vacancy_search_list&query=python'},
#  {'name': 'WEB/Data-аналитик',
#   'salary': '140\u202f000 – 200\u202f000 руб.',
#   'min_salary': 140000,
#   'max_salary': 200000,
#   'currency_salary': 'руб.',
#   'link': 'https://hh.ru/vacancy/76412397?from=vacancy_search_list&query=python'},
#  {'name': 'Python Backend Developer (middle)',
#   'salary': 'З/П не указана',
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'link': 'https://hh.ru/vacancy/76924747?from=vacancy_search_list&query=python'},
#  {'name': 'Разработчик Python (Middle, Senior)',
#   'salary': 'З/П не указана',
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'link': 'https://hh.ru/vacancy/55088580?from=vacancy_search_list&query=python'},
#  {'name': 'Программист-разработчик Python',
#   'salary': 'З/П не указана',
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'link': 'https://hh.ru/vacancy/69900189?from=vacancy_search_list&query=python'},
#  {'name': 'Python developer (проекты)',
#   'salary': 'З/П не указана',
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'link': 'https://hh.ru/vacancy/69533479?from=vacancy_search_list&query=python'},
#  {'name': 'Middle Python developer',
#   'salary': '120\u202f000 – 200\u202f000 руб.',
#   'min_salary': 120000,
#   'max_salary': 200000,
#   'currency_salary': 'руб.',
#   'link': 'https://hh.ru/vacancy/76595028?from=vacancy_search_list&query=python'},
#  {'name': 'Middle Python developer',
#   'salary': '150\u202f000 – 200\u202f000 руб.',
#   'min_salary': 150000,
#   'max_salary': 200000,
#   'currency_salary': 'руб.',
#   'link': 'https://hh.ru/vacancy/72687504?from=vacancy_search_list&query=python'},
#  {'name': 'Аналитик - разработчик (SQL+Python)',
#   'salary': 'З/П не указана',
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'link': 'https://hh.ru/vacancy/77000852?from=vacancy_search_list&query=python'},
#  {'name': 'Middle BackEnd разработчик (Python)',
#   'salary': 'З/П не указана',
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'link': 'https://hh.ru/vacancy/76445416?from=vacancy_search_list&query=python'},
#  {'name': 'Backend Python developer (senior/middle+)',
#   'salary': '150\u202f000 – 200\u202f000 руб.',
#   'min_salary': 150000,
#   'max_salary': 200000,
#   'currency_salary': 'руб.',
#   'link': 'https://hh.ru/vacancy/76827509?from=vacancy_search_list&query=python'},
#  {'name': 'Ведущий разработчик Python',
#   'salary': 'З/П не указана',
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'link': 'https://hh.ru/vacancy/73057608?from=vacancy_search_list&query=python'},
#  {'name': 'Программист Python - FastAPI',
#   'salary': 'от 180\u202f000 руб.',
#   'min_salary': 180000,
#   'max_salary': None,
#   'currency_salary': 'руб.',
#   'link': 'https://hh.ru/vacancy/77096692?from=vacancy_search_list&query=python'},
#  {'name': 'Middle Python-разработчик (торговый бот)',
#   'salary': 'З/П не указана',
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'link': 'https://hh.ru/vacancy/77196269?from=vacancy_search_list&query=python'},
#  {'name': 'Разработчик C (удаленная работа)',
#   'salary': 'до 350\u202f000 руб.',
#   'min_salary': None,
#   'max_salary': 350000,
#   'currency_salary': 'руб.',
#   'link': 'https://hh.ru/vacancy/76397262?from=vacancy_search_list&query=python'},
#  {'name': 'Разработчик Python (Senior)',
#   'salary': 'З/П не указана',
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'link': 'https://hh.ru/vacancy/73383410?from=vacancy_search_list&query=python'},
#  {'name': 'Middle/Senior Python разработчик (удаленно)',
#   'salary': 'до 250\u202f000 руб.',
#   'min_salary': None,
#   'max_salary': 250000,
#   'currency_salary': 'руб.',
#   'link': 'https://hh.ru/vacancy/76671759?from=vacancy_search_list&query=python'},
#  {'name': 'Главный разработчик Python',
#   'salary': '100\u202f000 – 200\u202f000 руб.',
#   'min_salary': 100000,
#   'max_salary': 200000,
#   'currency_salary': 'руб.',
#   'link': 'https://hh.ru/vacancy/70093763?from=vacancy_search_list&query=python'},
#  {'name': 'Специалист по добыче данных',
#   'salary': 'от 250\u202f000 руб.',
#   'min_salary': 250000,
#   'max_salary': None,
#   'currency_salary': 'руб.',
#   'link': 'https://hh.ru/vacancy/72352692?from=vacancy_search_list&query=python'},
#  {'name': 'Senior Python Developer (remote)',
#   'salary': 'до 7\u202f000 EUR',
#   'min_salary': None,
#   'max_salary': 7000,
#   'currency_salary': 'EUR',
#   'link': 'https://hh.ru/vacancy/77348459?from=vacancy_search_list&query=python'},
#  {'name': 'Python-разработчик (Middle)',
#   'salary': 'до 240\u202f000 руб.',
#   'min_salary': None,
#   'max_salary': 240000,
#   'currency_salary': 'руб.',
#   'link': 'https://hh.ru/vacancy/77276110?from=vacancy_search_list&query=python'},
#  {'name': 'Middle Python developer',
#   'salary': 'З/П не указана',
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'link': 'https://hh.ru/vacancy/77301676?from=vacancy_search_list&query=python'},
#  {'name': 'Разработчик бэкенда в Поиск',
#   'salary': 'З/П не указана',
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'link': 'https://hh.ru/vacancy/76567605?from=vacancy_search_list&query=python'},
#  {'name': 'Middle backend-разработчик Python',
#   'salary': 'З/П не указана',
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'link': 'https://hh.ru/vacancy/76140465?from=vacancy_search_list&query=python'},
#  {'name': 'PHP-разработчик (junior)',
#   'salary': 'от 60\u202f000 руб.',
#   'min_salary': 60000,
#   'max_salary': None,
#   'currency_salary': 'руб.',
#   'link': 'https://hh.ru/vacancy/77294716?from=vacancy_search_list&query=python'},
#  {'name': 'Python Engineer',
#   'salary': '3\u202f000 – 6\u202f500 USD',
#   'min_salary': 3000,
#   'max_salary': 6500,
#   'currency_salary': 'USD',
#   'link': 'https://hh.ru/vacancy/76983666?from=vacancy_search_list&query=python'},
#  {'name': 'Главный разработчик Python',
#   'salary': 'З/П не указана',
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'link': 'https://hh.ru/vacancy/77234497?from=vacancy_search_list&query=python'},
#  {'name': 'Разработчик Python+MS SQL+1C',
#   'salary': 'З/П не указана',
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'link': 'https://hh.ru/vacancy/75878225?from=vacancy_search_list&query=python'},
#  {'name': 'Педагог программирования для детей (Scratch, Minecraft, Python)',
#   'salary': 'от 200\u202f000 KZT',
#   'min_salary': 200000,
#   'max_salary': None,
#   'currency_salary': 'KZT',
#   'link': 'https://hh.ru/vacancy/77372800?from=vacancy_search_list&query=python'},
#  {'name': 'Ведущий программист / разработчик Linux',
#   'salary': 'от 300\u202f000 руб.',
#   'min_salary': 300000,
#   'max_salary': None,
#   'currency_salary': 'руб.',
#   'link': 'https://hh.ru/vacancy/76676726?from=vacancy_search_list&query=python'},
#  {'name': 'Team Lead Python backend (удаленно)',
#   'salary': 'З/П не указана',
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'link': 'https://hh.ru/vacancy/76445564?from=vacancy_search_list&query=python'},
#  {'name': 'SDET Python (Network Traffic Analyzer)',
#   'salary': 'З/П не указана',
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'link': 'https://hh.ru/vacancy/77241066?from=vacancy_search_list&query=python'},
#  {'name': 'Python developer',
#   'salary': 'З/П не указана',
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'link': 'https://hh.ru/vacancy/76544211?from=vacancy_search_list&query=python'},
#  {'name': 'Аналитик',
#   'salary': 'З/П не указана',
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'link': 'https://hh.ru/vacancy/77287472?from=vacancy_search_list&query=python'},
#  {'name': 'Аналитик корпоративных массивов данных (с навыками в Data Science, Machine Learning)',
#   'salary': 'З/П не указана',
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'link': 'https://hh.ru/vacancy/76385297?from=vacancy_search_list&query=python'},
#  {'name': 'Python TeamLead/Руководитель группы разработки Backend',
#   'salary': 'З/П не указана',
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'link': 'https://hh.ru/vacancy/77181373?from=vacancy_search_list&query=python'},
#  {'name': 'Программист Python',
#   'salary': 'З/П не указана',
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'link': 'https://hh.ru/vacancy/77065085?from=vacancy_search_list&query=python'},
#  {'name': 'BackEnd Developer (Python)',
#   'salary': 'З/П не указана',
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'link': 'https://hh.ru/vacancy/77264154?from=vacancy_search_list&query=python'},
#  {'name': 'Backend-разработчик Python',
#   'salary': '150\u202f000 – 250\u202f000 руб.',
#   'min_salary': 150000,
#   'max_salary': 250000,
#   'currency_salary': 'руб.',
#   'link': 'https://hh.ru/vacancy/75865798?from=vacancy_search_list&query=python'},
#  {'name': 'Software Engineer in Test (Python)',
#   'salary': 'З/П не указана',
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'link': 'https://hh.ru/vacancy/74803836?from=vacancy_search_list&query=python'},
#  {'name': 'Python Developer',
#   'salary': 'З/П не указана',
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'link': 'https://hh.ru/vacancy/76843829?from=vacancy_search_list&query=python'},
#  {'name': 'Преподаватель Python/Django',
#   'salary': 'З/П не указана',
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'link': 'https://hh.ru/vacancy/76217176?from=vacancy_search_list&query=python'},
#  {'name': 'Программист/разработчик Linux',
#   'salary': 'от 200\u202f000 руб.',
#   'min_salary': 200000,
#   'max_salary': None,
#   'currency_salary': 'руб.',
#   'link': 'https://hh.ru/vacancy/76676691?from=vacancy_search_list&query=python'},
#  {'name': 'Программист-разработчик компьютерного зрения (python)',
#   'salary': 'З/П не указана',
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'link': 'https://hh.ru/vacancy/77002334?from=vacancy_search_list&query=python'},
#  {'name': 'Ведущий разработчик Python',
#   'salary': 'З/П не указана',
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'link': 'https://hh.ru/vacancy/72398952?from=vacancy_search_list&query=python'},
#  {'name': 'Senior Python разработчик',
#   'salary': 'З/П не указана',
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'link': 'https://hh.ru/vacancy/76810518?from=vacancy_search_list&query=python'},
#  {'name': 'Аналитик-разработчик в качество Геопоиска',
#   'salary': 'З/П не указана',
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'link': 'https://hh.ru/vacancy/76204660?from=vacancy_search_list&query=python'},
#  {'name': 'Backend разработчик Middle +, Senior (Python)',
#   'salary': 'от 200\u202f000 руб.',
#   'min_salary': 200000,
#   'max_salary': None,
#   'currency_salary': 'руб.',
#   'link': 'https://hh.ru/vacancy/76345518?from=vacancy_search_list&query=python'},
#  {'name': 'ML Engineer / специалист Департамента розничных рисков',
#   'salary': 'З/П не указана',
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'link': 'https://hh.ru/vacancy/76930917?from=vacancy_search_list&query=python'},
#  {'name': 'Разработчик OCR/ML/NER (Python)',
#   'salary': 'З/П не указана',
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'link': 'https://hh.ru/vacancy/76220566?from=vacancy_search_list&query=python'},
#  {'name': 'Спикер на курс «Автотесты на Python. Продвинутая часть»',
#   'salary': 'З/П не указана',
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'link': 'https://hh.ru/vacancy/77235046?from=vacancy_search_list&query=python'},
#  {'name': 'Middle backend developer (Python), remote',
#   'salary': 'З/П не указана',
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'link': 'https://hh.ru/vacancy/74063789?from=vacancy_search_list&query=python'},
#  {'name': 'Руководитель разработки (ТехЛид) Python/Django',
#   'salary': 'З/П не указана',
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'link': 'https://hh.ru/vacancy/73076249?from=vacancy_search_list&query=python'},
#  {'name': 'Инженер по автоматизации тестирования Python',
#   'salary': 'З/П не указана',
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'link': 'https://hh.ru/vacancy/77332335?from=vacancy_search_list&query=python'},
#  {'name': 'Учитель программирования',
#   'salary': '30\u202f000 – 90\u202f000 руб.',
#   'min_salary': 30000,
#   'max_salary': 90000,
#   'currency_salary': 'руб.',
#   'link': 'https://hh.ru/vacancy/76397431?from=vacancy_search_list&query=python'},
#  {'name': 'Программист Python',
#   'salary': '125\u202f000 – 220\u202f000 руб.',
#   'min_salary': 125000,
#   'max_salary': 220000,
#   'currency_salary': 'руб.',
#   'link': 'https://hh.ru/vacancy/75845551?from=vacancy_search_list&query=python'},
#  {'name': 'Python Software Developer (AI)',
#   'salary': 'З/П не указана',
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'link': 'https://hh.ru/vacancy/76806633?from=vacancy_search_list&query=python'},
#  {'name': 'Программист Python php (Москва)',
#   'salary': '80\u202f000 – 100\u202f000 руб.',
#   'min_salary': 80000,
#   'max_salary': 100000,
#   'currency_salary': 'руб.',
#   'link': 'https://hh.ru/vacancy/77163195?from=vacancy_search_list&query=python'},
#  {'name': 'Senior QA automation (Python)',
#   'salary': 'до 300\u202f000 руб.',
#   'min_salary': None,
#   'max_salary': 300000,
#   'currency_salary': 'руб.',
#   'link': 'https://hh.ru/vacancy/72473393?from=vacancy_search_list&query=python'},
#  {'name': 'Разработчик Python Junior',
#   'salary': 'З/П не указана',
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'link': 'https://hh.ru/vacancy/74052153?from=vacancy_search_list&query=python'},
#  {'name': 'Python-разработчик (Senior)',
#   'salary': 'от 240\u202f000 руб.',
#   'min_salary': 240000,
#   'max_salary': None,
#   'currency_salary': 'руб.',
#   'link': 'https://hh.ru/vacancy/77331406?from=vacancy_search_list&query=python'},
#  {'name': 'Fullstack Разработчик',
#   'salary': 'от 50\u202f000 руб.',
#   'min_salary': 50000,
#   'max_salary': None,
#   'currency_salary': 'руб.',
#   'link': 'https://hh.ru/vacancy/77266384?from=vacancy_search_list&query=python'},
#  {'name': 'Главный python разработчик управления данными (ДПП)',
#   'salary': 'З/П не указана',
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'link': 'https://hh.ru/vacancy/76080775?from=vacancy_search_list&query=python'},
#  {'name': 'Middle OpenStack Python',
#   'salary': 'З/П не указана',
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'link': 'https://hh.ru/vacancy/75726638?from=vacancy_search_list&query=python'},
#  {'name': 'Python-разработчик (middle)',
#   'salary': 'З/П не указана',
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'link': 'https://hh.ru/vacancy/77289629?from=vacancy_search_list&query=python'},
#  {'name': 'Data-аналитик',
#   'salary': 'З/П не указана',
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'link': 'https://hh.ru/vacancy/76933775?from=vacancy_search_list&query=python'},
#  {'name': 'Python разработчик',
#   'salary': 'З/П не указана',
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'link': 'https://hh.ru/vacancy/76780632?from=vacancy_search_list&query=python'},
#  {'name': 'Python (опыт с Rust) разработчик (PT Sandbox)',
#   'salary': 'З/П не указана',
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'link': 'https://hh.ru/vacancy/76916725?from=vacancy_search_list&query=python'},
#  {'name': 'Python разработчик (проект Лаборатория измерительных систем)',
#   'salary': 'З/П не указана',
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'link': 'https://hh.ru/vacancy/77193986?from=vacancy_search_list&query=python'},
#  {'name': 'Разработчик базы данных',
#   'salary': 'З/П не указана',
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'link': 'https://hh.ru/vacancy/75522993?from=vacancy_search_list&query=python'},
#  {'name': 'Программист-разработчик компьютерного зрения (python)',
#   'salary': 'З/П не указана',
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'link': 'https://hh.ru/vacancy/77002334?from=vacancy_search_list&query=python'},
#  {'name': 'Python разработчик Junior',
#   'salary': '40\u202f000 – 60\u202f000 руб.',
#   'min_salary': 40000,
#   'max_salary': 60000,
#   'currency_salary': 'руб.',
#   'link': 'https://hh.ru/vacancy/76757250?from=vacancy_search_list&query=python'},
#  {'name': 'Software Engineer in Test (Python)',
#   'salary': 'З/П не указана',
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'link': 'https://hh.ru/vacancy/74803836?from=vacancy_search_list&query=python'},
#  {'name': 'Программист-разработчик',
#   'salary': 'от 85\u202f000 руб.',
#   'min_salary': 85000,
#   'max_salary': None,
#   'currency_salary': 'руб.',
#   'link': 'https://hh.ru/vacancy/77192679?from=vacancy_search_list&query=python'},
#  {'name': 'Python Team Lead',
#   'salary': 'З/П не указана',
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'link': 'https://hh.ru/vacancy/76707495?from=vacancy_search_list&query=python'},
#  {'name': 'Программист',
#   'salary': 'З/П не указана',
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'link': 'https://hh.ru/vacancy/76800949?from=vacancy_search_list&query=python'},
#  {'name': 'Data Engineer',
#   'salary': 'З/П не указана',
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'link': 'https://hh.ru/vacancy/76068416?from=vacancy_search_list&query=python'},
#  {'name': 'Программист/разработчик Linux',
#   'salary': 'от 200\u202f000 руб.',
#   'min_salary': 200000,
#   'max_salary': None,
#   'currency_salary': 'руб.',
#   'link': 'https://hh.ru/vacancy/76676691?from=vacancy_search_list&query=python'},
#  {'name': 'Стажер Sberseasons осень 2022 Data Science Новосибирск',
#   'salary': 'З/П не указана',
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'link': 'https://hh.ru/vacancy/77053286?from=vacancy_search_list&query=python'},
#  {'name': 'Junior Data Analyst',
#   'salary': 'З/П не указана',
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'link': 'https://hh.ru/vacancy/76902009?from=vacancy_search_list&query=python'},
#  {'name': 'Ведущий/Старший разработчик Python',
#   'salary': 'З/П не указана',
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'link': 'https://hh.ru/vacancy/77082725?from=vacancy_search_list&query=python'},
#  {'name': 'Системный администратор Linux (Казань)',
#   'salary': 'от 180\u202f000 руб.',
#   'min_salary': 180000,
#   'max_salary': None,
#   'currency_salary': 'руб.',
#   'link': 'https://hh.ru/vacancy/76115945?from=vacancy_search_list&query=python'},
#  {'name': 'Аналитик-разработчик в качество Геопоиска',
#   'salary': 'З/П не указана',
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'link': 'https://hh.ru/vacancy/76204659?from=vacancy_search_list&query=python'},
#  {'name': 'Senior/Middle Python разработчик',
#   'salary': 'З/П не указана',
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'link': 'https://hh.ru/vacancy/74351176?from=vacancy_search_list&query=python'},
#  {'name': 'Программист',
#   'salary': 'от 100\u202f000 руб.',
#   'min_salary': 100000,
#   'max_salary': None,
#   'currency_salary': 'руб.',
#   'link': 'https://hh.ru/vacancy/77312535?from=vacancy_search_list&query=python'},
#  {'name': 'Team Lead (Python)',
#   'salary': 'З/П не указана',
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'link': 'https://hh.ru/vacancy/76810563?from=vacancy_search_list&query=python'},
#  {'name': 'Python Developer',
#   'salary': 'З/П не указана',
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'link': 'https://hh.ru/vacancy/76000148?from=vacancy_search_list&query=python'},
#  {'name': 'Тестировщик (Automation engineer Selenium)',
#   'salary': 'от 140\u202f000 руб.',
#   'min_salary': 140000,
#   'max_salary': None,
#   'currency_salary': 'руб.',
#   'link': 'https://hh.ru/vacancy/76346773?from=vacancy_search_list&query=python'},
#  {'name': 'Разработчик Python (Senior)',
#   'salary': 'З/П не указана',
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'link': 'https://hh.ru/vacancy/73383410?from=vacancy_search_list&query=python'},
#  {'name': 'SDET Python (Network Traffic Analyzer)',
#   'salary': 'З/П не указана',
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'link': 'https://hh.ru/vacancy/77241066?from=vacancy_search_list&query=python'},
#  {'name': 'Teamlead Python developer, удаленно',
#   'salary': 'З/П не указана',
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'link': 'https://hh.ru/vacancy/77321451?from=vacancy_search_list&query=python'},
#  {'name': 'FPGA DSP разработчик',
#   'salary': 'З/П не указана',
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'link': 'https://hh.ru/vacancy/76971851?from=vacancy_search_list&query=python'},
#  {'name': 'Стажер в отдел DevOps',
#   'salary': 'З/П не указана',
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'link': 'https://hh.ru/vacancy/77179421?from=vacancy_search_list&query=python'},
#  {'name': 'ML Engineer / специалист Департамента розничных рисков',
#   'salary': 'З/П не указана',
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'link': 'https://hh.ru/vacancy/76930917?from=vacancy_search_list&query=python'},
#  {'name': 'Python разработчик',
#   'salary': 'З/П не указана',
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'link': 'https://hh.ru/vacancy/76829343?from=vacancy_search_list&query=python'},
#  {'name': 'TeamLead Python/C++',
#   'salary': 'З/П не указана',
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'link': 'https://hh.ru/vacancy/76454509?from=vacancy_search_list&query=python'},
#  {'name': 'Программист',
#   'salary': 'З/П не указана',
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'link': 'https://hh.ru/vacancy/76773259?from=vacancy_search_list&query=python'},
#  {'name': 'ML-Researcher (NLP)',
#   'salary': 'от 210\u202f000 руб.',
#   'min_salary': 210000,
#   'max_salary': None,
#   'currency_salary': 'руб.',
#   'link': 'https://hh.ru/vacancy/76006351?from=vacancy_search_list&query=python'},
#  {'name': 'Senior Python+Go developer',
#   'salary': '300\u202f000 – 350\u202f000 руб.',
#   'min_salary': 300000,
#   'max_salary': 350000,
#   'currency_salary': 'руб.',
#   'link': 'https://hh.ru/vacancy/77223951?from=vacancy_search_list&query=python'},
#  {'name': 'Главный разработчик Python',
#   'salary': 'З/П не указана',
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'link': 'https://hh.ru/vacancy/77234497?from=vacancy_search_list&query=python'},
#  {'name': 'Руководитель группы разработки Python (Senior/TechLead/TeamLead)',
#   'salary': 'З/П не указана',
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'link': 'https://hh.ru/vacancy/76939956?from=vacancy_search_list&query=python'},
#  {'name': 'Инженер-программист (Python)',
#   'salary': 'З/П не указана',
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'link': 'https://hh.ru/vacancy/69100495?from=vacancy_search_list&query=python'},
#  {'name': 'Разработчик Python',
#   'salary': 'З/П не указана',
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'link': 'https://hh.ru/vacancy/76851801?from=vacancy_search_list&query=python'},
#  {'name': 'Программист-разработчик',
#   'salary': 'от 140\u202f000 руб.',
#   'min_salary': 140000,
#   'max_salary': None,
#   'currency_salary': 'руб.',
# ...
#  {'name': 'DevSecOps',
#   'salary': 'З/П не указана',
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'link': 'https://hh.ru/vacancy/76406255?from=vacancy_search_list&query=python'},
#  {'name': 'C++ Senior Software Programmer',
#   'salary': 'от 6\u202f300 EUR',
#   'min_salary': 6300,
#   'max_salary': None,
#   'currency_salary': 'EUR',
#   'link': 'https://hh.ru/vacancy/76684492?from=vacancy_search_list&query=python'},
#  {'name': 'Game Product Analyst',
#   'salary': 'З/П не указана',
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'link': 'https://hh.ru/vacancy/76653183?from=vacancy_search_list&query=python'},
#  {'name': 'Automation QA Specialist',
#   'salary': 'З/П не указана',
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'link': 'https://hh.ru/vacancy/52346968?from=vacancy_search_list&query=python'},
#  {'name': 'Middle DevOps Engineer',
#   'salary': '103\u202f500 – 200\u202f000 руб.',
#   'min_salary': 103500,
#   'max_salary': 200000,
#   'currency_salary': 'руб.',
#   'link': 'https://hh.ru/vacancy/76477786?from=vacancy_search_list&query=python'},
#  {'name': 'Программист Perl',
#   'salary': 'от 150\u202f000 руб.',
#   'min_salary': 150000,
#   'max_salary': None,
#   'currency_salary': 'руб.',
#   'link': 'https://hh.ru/vacancy/67617122?from=vacancy_search_list&query=python'},
#  {'name': 'Программист API/API Developer',
#   'salary': 'З/П не указана',
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'link': 'https://hh.ru/vacancy/77280332?from=vacancy_search_list&query=python'},
#  {'name': 'Rust Developer',
#   'salary': 'от 2\u202f000 EUR',
#   'min_salary': 2000,
#   'max_salary': None,
#   'currency_salary': 'EUR',
#   'link': 'https://hh.ru/vacancy/77199590?from=vacancy_search_list&query=python'},
#  {'name': 'Сетевой инженер-программист',
#   'salary': 'от 160\u202f000 руб.',
#   'min_salary': 160000,
#   'max_salary': None,
#   'currency_salary': 'руб.',
#   'link': 'https://hh.ru/vacancy/77279011?from=vacancy_search_list&query=python'},
#  {'name': 'QA automation engineer',
#   'salary': 'от 120\u202f000 руб.',
#   'min_salary': 120000,
#   'max_salary': None,
#   'currency_salary': 'руб.',
#   'link': 'https://hh.ru/vacancy/77215426?from=vacancy_search_list&query=python'},
#  {'name': 'Machine learning engineer (проект "Группы")',
#   'salary': 'З/П не указана',
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'link': 'https://hh.ru/vacancy/68447647?from=vacancy_search_list&query=python'},
#  {'name': 'Senior Python Developer / Data Engineer в команду Data Catalog, платформа ML Space',
#   'salary': 'З/П не указана',
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'link': 'https://hh.ru/vacancy/71902418?from=vacancy_search_list&query=python'},
#  {'name': 'QA Automation Engineer',
#   'salary': 'З/П не указана',
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'link': 'https://hh.ru/vacancy/74803721?from=vacancy_search_list&query=python'},
#  {'name': 'Data Engineer в Практикум',
#   'salary': 'З/П не указана',
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'link': 'https://hh.ru/vacancy/77037098?from=vacancy_search_list&query=python'},
#  {'name': 'Machine learning engineer (проект "Группы")',
#   'salary': 'З/П не указана',
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'link': 'https://hh.ru/vacancy/68447646?from=vacancy_search_list&query=python'},
#  {'name': 'Инженер по нагрузочному тестированию',
#   'salary': 'З/П не указана',
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'link': 'https://hh.ru/vacancy/76558448?from=vacancy_search_list&query=python'},
#  {'name': 'Инженер-разработчик Data Science (проект "Лента")',
#   'salary': 'З/П не указана',
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'link': 'https://hh.ru/vacancy/48788339?from=vacancy_search_list&query=python'},
#  {'name': 'Senior Data Scientist',
#   'salary': 'З/П не указана',
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'link': 'https://hh.ru/vacancy/76333170?from=vacancy_search_list&query=python'},
#  {'name': 'Аналитик-разработчик',
#   'salary': 'З/П не указана',
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'link': 'https://hh.ru/vacancy/76519651?from=vacancy_search_list&query=python'},
#  {'name': 'Разработчик C (удаленная работа)',
#   'salary': 'до 350\u202f000 руб.',
#   'min_salary': None,
#   'max_salary': 350000,
#   'currency_salary': 'руб.',
#   'link': 'https://hh.ru/vacancy/76397262?from=vacancy_search_list&query=python'},
#  {'name': 'Data Engineer',
#   'salary': 'З/П не указана',
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'link': 'https://hh.ru/vacancy/74923706?from=vacancy_search_list&query=python'},
#  {'name': 'Системный администратор Linux',
#   'salary': 'от 150\u202f000 руб.',
#   'min_salary': 150000,
#   'max_salary': None,
#   'currency_salary': 'руб.',
#   'link': 'https://hh.ru/vacancy/76436539?from=vacancy_search_list&query=python'},
#  {'name': 'Game analyst',
#   'salary': 'З/П не указана',
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'link': 'https://hh.ru/vacancy/76637243?from=vacancy_search_list&query=python'},
#  {'name': 'Linux инженер',
#   'salary': 'З/П не указана',
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'link': 'https://hh.ru/vacancy/76381460?from=vacancy_search_list&query=python'},
#  {'name': 'Аналитик данных',
#   'salary': 'З/П не указана',
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'link': 'https://hh.ru/vacancy/73204336?from=vacancy_search_list&query=python'},
#  {'name': 'Разработчик в команду робототехники Маркета',
#   'salary': 'З/П не указана',
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'link': 'https://hh.ru/vacancy/70366583?from=vacancy_search_list&query=python'},
#  {'name': 'Data Analyst в команду Боты.KnowledgeAssistant',
#   'salary': 'З/П не указана',
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'link': 'https://hh.ru/vacancy/77358542?from=vacancy_search_list&query=python'},
#  {'name': 'QA engineer',
#   'salary': 'З/П не указана',
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'link': 'https://hh.ru/vacancy/77033072?from=vacancy_search_list&query=python'},
#  {'name': 'Cистемный администратор Linux',
#   'salary': 'З/П не указана',
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'link': 'https://hh.ru/vacancy/76486039?from=vacancy_search_list&query=python'},
#  {'name': 'Senior DevOps Engineer',
#   'salary': 'до 300\u202f000 руб.',
#   'min_salary': None,
#   'max_salary': 300000,
#   'currency_salary': 'руб.',
#   'link': 'https://hh.ru/vacancy/74416079?from=vacancy_search_list&query=python'},
#  {'name': 'C++ разработчик алгоритмов геометрического моделирования',
#   'salary': '75\u202f000 – 140\u202f000 руб.',
#   'min_salary': 75000,
#   'max_salary': 140000,
#   'currency_salary': 'руб.',
#   'link': 'https://hh.ru/vacancy/76750972?from=vacancy_search_list&query=python'},
#  {'name': 'DevOps инженер',
#   'salary': 'З/П не указана',
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'link': 'https://hh.ru/vacancy/77285326?from=vacancy_search_list&query=python'},
#  {'name': 'DevOps Engineer',
#   'salary': 'З/П не указана',
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'link': 'https://hh.ru/vacancy/76423592?from=vacancy_search_list&query=python'},
#  {'name': 'DevOps-инженер',
#   'salary': 'З/П не указана',
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'link': 'https://hh.ru/vacancy/76049271?from=vacancy_search_list&query=python'},
#  {'name': 'DevOps engineer',
#   'salary': 'З/П не указана',
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'link': 'https://hh.ru/vacancy/76555886?from=vacancy_search_list&query=python'},
#  {'name': 'DevOps Engineer (Tanks Blitz)',
#   'salary': 'З/П не указана',
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'link': 'https://hh.ru/vacancy/76382359?from=vacancy_search_list&query=python'},
#  {'name': 'Специалист по работе с базами данных / BI-аналитик',
#   'salary': '60\u202f000 – 70\u202f000 руб.',
#   'min_salary': 60000,
#   'max_salary': 70000,
#   'currency_salary': 'руб.',
#   'link': 'https://hh.ru/vacancy/76654818?from=vacancy_search_list&query=python'},
#  {'name': 'Data Engineer',
#   'salary': 'З/П не указана',
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'link': 'https://hh.ru/vacancy/71625886?from=vacancy_search_list&query=python'},
#  {'name': 'Технический писатель',
#   'salary': 'З/П не указана',
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'link': 'https://hh.ru/vacancy/77370133?from=vacancy_search_list&query=python'},
#  {'name': 'Системный администратор Linux (DevOps engineer)',
#   'salary': '130\u202f000 – 170\u202f000 руб.',
#   'min_salary': 130000,
#   'max_salary': 170000,
#   'currency_salary': 'руб.',
#   'link': 'https://hh.ru/vacancy/76541868?from=vacancy_search_list&query=python'},
#  {'name': 'Middle backend developer (Golang)',
#   'salary': 'до 250\u202f000 руб.',
#   'min_salary': None,
#   'max_salary': 250000,
#   'currency_salary': 'руб.',
#   'link': 'https://hh.ru/vacancy/76566819?from=vacancy_search_list&query=python'},
#  {'name': 'AppSec - аналитик',
#   'salary': 'З/П не указана',
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'link': 'https://hh.ru/vacancy/74409560?from=vacancy_search_list&query=python'},
#  {'name': 'Разработчик встраиваемого ПО под Linux',
#   'salary': 'З/П не указана',
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'link': 'https://hh.ru/vacancy/76669647?from=vacancy_search_list&query=python'},
#  {'name': 'Программист C',
#   'salary': 'от 150\u202f000 руб.',
#   'min_salary': 150000,
#   'max_salary': None,
#   'currency_salary': 'руб.',
#   'link': 'https://hh.ru/vacancy/75919839?from=vacancy_search_list&query=python'},
#  {'name': 'Инженер-программист С++',
#   'salary': 'З/П не указана',
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'link': 'https://hh.ru/vacancy/73400224?from=vacancy_search_list&query=python'},
#  {'name': 'Программист инструментария / Game Tools Developer',
#   'salary': 'З/П не указана',
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'link': 'https://hh.ru/vacancy/68381561?from=vacancy_search_list&query=python'},
#  {'name': 'C++ Разработчик в Браузер',
#   'salary': 'З/П не указана',
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'link': 'https://hh.ru/vacancy/76204816?from=vacancy_search_list&query=python'},
#  {'name': 'Senior Backend Engineer (Remote, to Canada/USA)',
#   'salary': '5\u202f000 – 7\u202f000 USD',
#   'min_salary': 5000,
#   'max_salary': 7000,
#   'currency_salary': 'USD',
#   'link': 'https://hh.ru/vacancy/76458727?from=vacancy_search_list&query=python'},
#  {'name': 'Senior Backend Engineer (Remote)',
#   'salary': '5\u202f000 – 7\u202f000 USD',
#   'min_salary': 5000,
#   'max_salary': 7000,
#   'currency_salary': 'USD',
#   'link': 'https://hh.ru/vacancy/76522811?from=vacancy_search_list&query=python'},
#  {'name': 'Google Cloud Platform (GCP) Data Engineer',
#   'salary': '3\u202f000 – 5\u202f000 USD',
#   'min_salary': 3000,
#   'max_salary': 5000,
#   'currency_salary': 'USD',
#   'link': 'https://hh.ru/vacancy/76684232?from=vacancy_search_list&query=python'},
#  {'name': 'Продуктовый аналитик',
#   'salary': 'З/П не указана',
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'link': 'https://hh.ru/vacancy/76218409?from=vacancy_search_list&query=python'},
#  {'name': 'Senior DevOps',
#   'salary': 'до 400\u202f000 руб.',
#   'min_salary': None,
#   'max_salary': 400000,
#   'currency_salary': 'руб.',
#   'link': 'https://hh.ru/vacancy/77014448?from=vacancy_search_list&query=python'},
#  {'name': 'Разработчик С++ в Яндекс.Браузер',
#   'salary': 'З/П не указана',
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'link': 'https://hh.ru/vacancy/77233027?from=vacancy_search_list&query=python'},
#  {'name': 'CI Engineer',
#   'salary': 'от 5\u202f000 USD',
#   'min_salary': 5000,
#   'max_salary': None,
#   'currency_salary': 'USD',
#   'link': 'https://hh.ru/vacancy/76770084?from=vacancy_search_list&query=python'},
#  {'name': 'Разработчик С++ в Яндекс.Браузер',
#   'salary': 'З/П не указана',
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'link': 'https://hh.ru/vacancy/77233030?from=vacancy_search_list&query=python'},
#  {'name': 'Инженер сопровождения и автоматизации',
#   'salary': 'З/П не указана',
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'link': 'https://hh.ru/vacancy/77145937?from=vacancy_search_list&query=python'},
#  {'name': 'DBA PostgreSQL/Администратор баз данных',
#   'salary': 'З/П не указана',
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'link': 'https://hh.ru/vacancy/66987957?from=vacancy_search_list&query=python'},
#  {'name': 'Fraud Activity Analyst',
#   'salary': 'З/П не указана',
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'link': 'https://hh.ru/vacancy/76704863?from=vacancy_search_list&query=python'},
#  {'name': 'QA Engineer (Junior)',
#   'salary': 'З/П не указана',
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'link': 'https://hh.ru/vacancy/76590365?from=vacancy_search_list&query=python'},
#  {'name': 'Аналитик в группу аналитики рынка',
#   'salary': 'З/П не указана',
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'link': 'https://hh.ru/vacancy/76829091?from=vacancy_search_list&query=python'},
#  {'name': 'Разработчик fullstack',
#   'salary': '40\u202f000 – 80\u202f000 руб.',
#   'min_salary': 40000,
#   'max_salary': 80000,
#   'currency_salary': 'руб.',
#   'link': 'https://hh.ru/vacancy/76984981?from=vacancy_search_list&query=python'},
#  {'name': 'Системный программист / разработчик С/C++ (LINUX)',
#   'salary': 'от 80\u202f000 руб.',
#   'min_salary': 80000,
#   'max_salary': None,
#   'currency_salary': 'руб.',
#   'link': 'https://hh.ru/vacancy/77092805?from=vacancy_search_list&query=python'},
#  {'name': 'Инженер внедрения программного обеспечения',
#   'salary': 'до 170\u202f000 руб.',
#   'min_salary': None,
#   'max_salary': 170000,
#   'currency_salary': 'руб.',
#   'link': 'https://hh.ru/vacancy/75556406?from=vacancy_search_list&query=python'},
#  {'name': 'Руководитель группы/лаборатории Reinforcement Learning',
#   'salary': 'от 200\u202f000 руб.',
#   'min_salary': 200000,
#   'max_salary': None,
#   'currency_salary': 'руб.',
#   'link': 'https://hh.ru/vacancy/76949717?from=vacancy_search_list&query=python'},
#  {'name': 'Преподаватель по программированию',
#   'salary': '20\u202f000 – 70\u202f000 руб.',
#   'min_salary': 20000,
#   'max_salary': 70000,
#   'currency_salary': 'руб.',
#   'link': 'https://hh.ru/vacancy/76844666?from=vacancy_search_list&query=python'},
#  {'name': 'Lead data scientist (Анализ цены и Trade in)',
#   'salary': 'З/П не указана',
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'link': 'https://hh.ru/vacancy/76954383?from=vacancy_search_list&query=python'},
#  {'name': 'Системный администратор СУБД (Junior)',
#   'salary': 'З/П не указана',
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'link': 'https://hh.ru/vacancy/77303268?from=vacancy_search_list&query=python'},
#  {'name': 'Реверс-инженер',
#   'salary': '100\u202f000 – 160\u202f000 руб.',
#   'min_salary': 100000,
#   'max_salary': 160000,
#   'currency_salary': 'руб.',
#   'link': 'https://hh.ru/vacancy/54462736?from=vacancy_search_list&query=python'},
#  {'name': 'Tools Programmer C++ (Мир танков)',
#   'salary': 'З/П не указана',
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'link': 'https://hh.ru/vacancy/77120762?from=vacancy_search_list&query=python'}]

# %%
len(vacancy_list)
# Out:
# 780
