# %% [markdown]
# <a href="https://colab.research.google.com/github/Hanna413/Parsing_GB/blob/Lesson3_BeautifulSoup/Parsing3_HW.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from bs4 import BeautifulSoup as bs
import requests
from time import sleep

# %%
def page_for_parsing(vacancy_name, num_page):

    url = 'https://hh.ru/search/vacancy'

    headers = {
            'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/110.0.0.0 Safari/537.36',
            }

    params = {'text': vacancy_name, 'page': num_page}

    return requests.get(url=url, headers=headers, params=params)

# %%
def clean_salary(vacancy_salary_text, min_salary=None, max_salary=None, currency_salary=None):
  list_salary = vacancy_salary_text.replace('\u202f', '').split()
  for i in range(len(list_salary) - 1):
    if list_salary[i] == 'от':
      min_salary = int(list_salary[i + 1])
    elif list_salary[i] == 'до':
      max_salary = int(list_salary[i + 1])
    elif list_salary[i] == '–':
      min_salary = int(list_salary[i - 1])
      max_salary = int(list_salary[i + 1])
  currency_salary = list_salary[-1]

  return min_salary, max_salary, currency_salary

# %%
vacancy_list = []
for page in range(0, 40):
  response = page_for_parsing('python', page)
  
  #print(response.url)
  soup = bs(response.content, 'html.parser')
  vacancies = soup.find_all('div',{'class': 'vacancy-serp-item__layout'})
  for vacancy in vacancies:
    vacancy_name = vacancy.find('a').text

    vacancy_salary = vacancy.find('span', {'class', 'bloko-header-section-3'})
    if vacancy_salary:
      vacancy_salary = vacancy_salary.text
      min_salary, max_salary, currency_salary = clean_salary(vacancy_salary)
    else:
      vacancy_salary = 'З/П не указана'
      min_salary, max_salary, currency_salary = None, None, None

    vacancy_link = vacancy.find('a')['href']

    vacancy_dict = {
        'name': vacancy_name,
        'salary' : vacancy_salary,
        'min_salary': min_salary,
        'max_salary': max_salary,
        'currency_salary': currency_salary,
        'link' : vacancy_link,
        'source' : 'hh.ru'
    }

    vacancy_list.append(vacancy_dict)

  i += 1
  sleep(0.1)

# %%
vacancy_list
# Out:
# [{'name': 'Ведущий инженер по тестированию (python)',
#   'salary': 'З/П не указана',
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'link': 'https://hh.ru/vacancy/73199414?from=vacancy_search_list&query=python',
#   'source': 'hh.ru'},
#  {'name': 'Аналитик данных / Data Analyst',
#   'salary': 'З/П не указана',
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'link': 'https://hh.ru/vacancy/69166398?from=vacancy_search_list&query=python',
#   'source': 'hh.ru'},
#  {'name': 'Аналитик данных / Data Analyst',
#   'salary': 'З/П не указана',
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'link': 'https://hh.ru/vacancy/76869170?from=vacancy_search_list&query=python',
#   'source': 'hh.ru'},
#  {'name': 'Преподаватель Backend направления',
#   'salary': '6\u202f000\u202f000 – 10\u202f000\u202f000 сум',
#   'min_salary': 6000000,
#   'max_salary': 10000000,
#   'currency_salary': 'сум',
#   'link': 'https://hh.ru/vacancy/77349432?from=vacancy_search_list&query=python',
#   'source': 'hh.ru'},
#  {'name': 'Младший инженер по тестированию (QA performance engineer Junior)',
#   'salary': 'З/П не указана',
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'link': 'https://hh.ru/vacancy/76087775?from=vacancy_search_list&query=python',
#   'source': 'hh.ru'},
#  {'name': 'Специалист по углубленной аналитике данных (Data scientist)',
#   'salary': 'З/П не указана',
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'link': 'https://hh.ru/vacancy/72920605?from=vacancy_search_list&query=python',
#   'source': 'hh.ru'},
#  {'name': 'SQL разработчик',
#   'salary': 'З/П не указана',
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'link': 'https://hh.ru/vacancy/77286859?from=vacancy_search_list&query=python',
#   'source': 'hh.ru'},
#  {'name': 'Разработчик Python',
#   'salary': '200\u202f000 – 250\u202f000 руб.',
#   'min_salary': 200000,
#   'max_salary': 250000,
#   'currency_salary': 'руб.',
#   'link': 'https://hh.ru/vacancy/77091466?from=vacancy_search_list&query=python',
#   'source': 'hh.ru'},
#  {'name': 'Программист Python Junior',
#   'salary': 'З/П не указана',
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'link': 'https://hh.ru/vacancy/77146976?from=vacancy_search_list&query=python',
#   'source': 'hh.ru'},
#  {'name': 'Python-разработчик (Django, DRF)',
#   'salary': '60\u202f000 – 220\u202f000 руб.',
#   'min_salary': 60000,
#   'max_salary': 220000,
#   'currency_salary': 'руб.',
#   'link': 'https://hh.ru/vacancy/70705466?from=vacancy_search_list&query=python',
#   'source': 'hh.ru'},
#  {'name': 'Разработчик Python',
#   'salary': '200\u202f000 – 250\u202f000 руб.',
#   'min_salary': 200000,
#   'max_salary': 250000,
#   'currency_salary': 'руб.',
#   'link': 'https://hh.ru/vacancy/77091465?from=vacancy_search_list&query=python',
#   'source': 'hh.ru'},
#  {'name': 'Разработчик C# / Python',
#   'salary': '300\u202f000 – 500\u202f000 руб.',
#   'min_salary': 300000,
#   'max_salary': 500000,
#   'currency_salary': 'руб.',
#   'link': 'https://hh.ru/vacancy/71147348?from=vacancy_search_list&query=python',
#   'source': 'hh.ru'},
#  {'name': 'Python Backend Developer / WEB - разработчик',
#   'salary': '300\u202f000 – 450\u202f000 руб.',
#   'min_salary': 300000,
#   'max_salary': 450000,
#   'currency_salary': 'руб.',
#   'link': 'https://hh.ru/vacancy/72216524?from=vacancy_search_list&query=python',
#   'source': 'hh.ru'},
#  {'name': 'Ведущий Python разработчик (удаленка)',
#   'salary': 'до 8\u202f000 USD',
#   'min_salary': None,
#   'max_salary': 8000,
#   'currency_salary': 'USD',
#   'link': 'https://hh.ru/vacancy/76832091?from=vacancy_search_list&query=python',
#   'source': 'hh.ru'},
#  {'name': 'Backend (Python) инженер',
#   'salary': '800\u202f000 – 1\u202f300\u202f000 KZT',
#   'min_salary': 800000,
#   'max_salary': 1300000,
#   'currency_salary': 'KZT',
#   'link': 'https://hh.ru/vacancy/77382317?from=vacancy_search_list&query=python',
#   'source': 'hh.ru'},
#  {'name': 'Junior+ Python Backend Developer',
#   'salary': 'до 120\u202f000 руб.',
#   'min_salary': None,
#   'max_salary': 120000,
#   'currency_salary': 'руб.',
#   'link': 'https://hh.ru/vacancy/77372405?from=vacancy_search_list&query=python',
#   'source': 'hh.ru'},
#  {'name': 'Backend developer (Python)',
#   'salary': '60\u202f000 – 150\u202f000 руб.',
#   'min_salary': 60000,
#   'max_salary': 150000,
#   'currency_salary': 'руб.',
#   'link': 'https://hh.ru/vacancy/76716478?from=vacancy_search_list&query=python',
#   'source': 'hh.ru'},
#  {'name': 'Junior+ программист-разработчик на Python',
#   'salary': 'до 150\u202f000 руб.',
#   'min_salary': None,
#   'max_salary': 150000,
#   'currency_salary': 'руб.',
#   'link': 'https://hh.ru/vacancy/77357729?from=vacancy_search_list&query=python',
#   'source': 'hh.ru'},
#  {'name': 'Python разработчик',
#   'salary': 'от 25\u202f000 руб.',
#   'min_salary': 25000,
#   'max_salary': None,
#   'currency_salary': 'руб.',
#   'link': 'https://hh.ru/vacancy/76818478?from=vacancy_search_list&query=python',
#   'source': 'hh.ru'},
#  {'name': 'Python Developer по работе с ChatGPT (генеративным AI)',
#   'salary': 'З/П не указана',
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'link': 'https://hh.ru/vacancy/77144612?from=vacancy_search_list&query=python',
#   'source': 'hh.ru'},
#  {'name': 'Программист Python (Django)',
#   'salary': '160\u202f000 – 180\u202f000 руб.',
#   'min_salary': 160000,
#   'max_salary': 180000,
#   'currency_salary': 'руб.',
#   'link': 'https://hh.ru/vacancy/76826004?from=vacancy_search_list&query=python',
#   'source': 'hh.ru'},
#  {'name': 'Ведущий Python Backend разработчик',
#   'salary': 'до 5\u202f000 USD',
#   'min_salary': None,
#   'max_salary': 5000,
#   'currency_salary': 'USD',
#   'link': 'https://hh.ru/vacancy/77304894?from=vacancy_search_list&query=python',
#   'source': 'hh.ru'},
#  {'name': 'Backend-разработчик / Python developer',
#   'salary': '100\u202f000 – 200\u202f000 руб.',
#   'min_salary': 100000,
#   'max_salary': 200000,
#   'currency_salary': 'руб.',
#   'link': 'https://hh.ru/vacancy/76358462?from=vacancy_search_list&query=python',
#   'source': 'hh.ru'},
#  {'name': 'Начинающий программист BI (sql/python/js)',
#   'salary': '50\u202f000 – 70\u202f000 руб.',
#   'min_salary': 50000,
#   'max_salary': 70000,
#   'currency_salary': 'руб.',
#   'link': 'https://hh.ru/vacancy/76569529?from=vacancy_search_list&query=python',
#   'source': 'hh.ru'},
#  {'name': 'Data Scientist middle+/Senior',
#   'salary': '250\u202f000 – 350\u202f000 руб.',
#   'min_salary': 250000,
#   'max_salary': 350000,
#   'currency_salary': 'руб.',
#   'link': 'https://hh.ru/vacancy/77208642?from=vacancy_search_list&query=python',
#   'source': 'hh.ru'},
#  {'name': 'Аналитик данных / Data Analyst',
#   'salary': '160\u202f000 – 200\u202f000 руб.',
#   'min_salary': 160000,
#   'max_salary': 200000,
#   'currency_salary': 'руб.',
#   'link': 'https://hh.ru/vacancy/77334669?from=vacancy_search_list&query=python',
#   'source': 'hh.ru'},
#  {'name': 'Python-developer',
#   'salary': '100\u202f000 – 215\u202f000 руб.',
#   'min_salary': 100000,
#   'max_salary': 215000,
#   'currency_salary': 'руб.',
#   'link': 'https://hh.ru/vacancy/67635148?from=vacancy_search_list&query=python',
#   'source': 'hh.ru'},
#  {'name': 'Data Analyst (Remote)',
#   'salary': '3\u202f000 – 4\u202f000 USD',
#   'min_salary': 3000,
#   'max_salary': 4000,
#   'currency_salary': 'USD',
#   'link': 'https://hh.ru/vacancy/74736549?from=vacancy_search_list&query=python',
#   'source': 'hh.ru'},
#  {'name': 'Удаленный стажер-аналитик (графовые базы данных)',
#   'salary': 'З/П не указана',
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'link': 'https://hh.ru/vacancy/77347089?from=vacancy_search_list&query=python',
#   'source': 'hh.ru'},
#  {'name': 'Backend разработчик Python',
#   'salary': '35\u202f000 – 50\u202f000 руб.',
#   'min_salary': 35000,
#   'max_salary': 50000,
#   'currency_salary': 'руб.',
#   'link': 'https://hh.ru/vacancy/77336288?from=vacancy_search_list&query=python',
#   'source': 'hh.ru'},
#  {'name': 'Data Scientist',
#   'salary': '160\u202f000 – 200\u202f000 руб.',
#   'min_salary': 160000,
#   'max_salary': 200000,
#   'currency_salary': 'руб.',
#   'link': 'https://hh.ru/vacancy/76925483?from=vacancy_search_list&query=python',
#   'source': 'hh.ru'},
#  {'name': 'Разработчик бэкэнд (Python)',
#   'salary': '150\u202f000 – 180\u202f000 руб.',
#   'min_salary': 150000,
#   'max_salary': 180000,
#   'currency_salary': 'руб.',
#   'link': 'https://hh.ru/vacancy/76712573?from=vacancy_search_list&query=python',
#   'source': 'hh.ru'},
#  {'name': 'Python Backend Developer / Data Engineer',
#   'salary': 'до 250\u202f000 руб.',
#   'min_salary': None,
#   'max_salary': 250000,
#   'currency_salary': 'руб.',
#   'link': 'https://hh.ru/vacancy/77121880?from=vacancy_search_list&query=python',
#   'source': 'hh.ru'},
#  {'name': 'Стажер',
#   'salary': 'до 80\u202f000 руб.',
#   'min_salary': None,
#   'max_salary': 80000,
#   'currency_salary': 'руб.',
#   'link': 'https://hh.ru/vacancy/76809922?from=vacancy_search_list&query=python',
#   'source': 'hh.ru'},
#  {'name': 'АККРЕДИТОВАННАЯ КОМПАНИЯ Data Scientist / Python разработчик',
#   'salary': 'З/П не указана',
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'link': 'https://hh.ru/vacancy/48411370?from=vacancy_search_list&query=python',
#   'source': 'hh.ru'},
#  {'name': 'Middle Python developer (Казань)',
#   'salary': 'от 160\u202f000 руб.',
#   'min_salary': 160000,
#   'max_salary': None,
#   'currency_salary': 'руб.',
#   'link': 'https://hh.ru/vacancy/76115939?from=vacancy_search_list&query=python',
#   'source': 'hh.ru'},
#  {'name': 'Data Engineer',
#   'salary': '200\u202f000 – 280\u202f000 руб.',
#   'min_salary': 200000,
#   'max_salary': 280000,
#   'currency_salary': 'руб.',
#   'link': 'https://hh.ru/vacancy/77015802?from=vacancy_search_list&query=python',
#   'source': 'hh.ru'},
#  {'name': 'Python (Django) Backend developer',
#   'salary': 'до 280\u202f000 руб.',
#   'min_salary': None,
#   'max_salary': 280000,
#   'currency_salary': 'руб.',
#   'link': 'https://hh.ru/vacancy/76768230?from=vacancy_search_list&query=python',
#   'source': 'hh.ru'},
#  {'name': 'Python / JavaScript разработчик веб-приложений (Fullstack)',
#   'salary': '80\u202f000 – 120\u202f000 руб.',
#   'min_salary': 80000,
#   'max_salary': 120000,
#   'currency_salary': 'руб.',
#   'link': 'https://hh.ru/vacancy/77351026?from=vacancy_search_list&query=python',
#   'source': 'hh.ru'},
#  {'name': 'Artificial Intelligence / Machine Learning Engineer',
#   'salary': 'З/П не указана',
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'link': 'https://hh.ru/vacancy/77351701?from=vacancy_search_list&query=python',
#   'source': 'hh.ru'},
#  {'name': 'Python-разработчик в R&D отдел',
#   'salary': '100\u202f000 – 150\u202f000 руб.',
#   'min_salary': 100000,
#   'max_salary': 150000,
#   'currency_salary': 'руб.',
#   'link': 'https://hh.ru/vacancy/49299311?from=vacancy_search_list&query=python',
#   'source': 'hh.ru'},
#  {'name': 'Разработчик Python',
#   'salary': '30\u202f000 – 80\u202f000 руб.',
#   'min_salary': 30000,
#   'max_salary': 80000,
#   'currency_salary': 'руб.',
#   'link': 'https://hh.ru/vacancy/47668037?from=vacancy_search_list&query=python',
#   'source': 'hh.ru'},
#  {'name': 'Backend Developer Python',
#   'salary': 'З/П не указана',
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'link': 'https://hh.ru/vacancy/77365703?from=vacancy_search_list&query=python',
#   'source': 'hh.ru'},
#  {'name': 'Python developer (Банк)',
#   'salary': 'до 300\u202f000 руб.',
#   'min_salary': None,
#   'max_salary': 300000,
#   'currency_salary': 'руб.',
#   'link': 'https://hh.ru/vacancy/77262071?from=vacancy_search_list&query=python',
#   'source': 'hh.ru'},
#  {'name': 'Программист-стажер GO / Go Intern (Telecom)',
#   'salary': 'З/П не указана',
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'link': 'https://hh.ru/vacancy/77339852?from=vacancy_search_list&query=python',
#   'source': 'hh.ru'},
#  {'name': 'Python developer',
#   'salary': 'З/П не указана',
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'link': 'https://hh.ru/vacancy/77339906?from=vacancy_search_list&query=python',
#   'source': 'hh.ru'},
#  {'name': 'Python Developer',
#   'salary': 'З/П не указана',
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'link': 'https://hh.ru/vacancy/76498335?from=vacancy_search_list&query=python',
#   'source': 'hh.ru'},
#  {'name': 'Программист Python+Django',
#   'salary': 'от 25\u202f000 руб.',
#   'min_salary': 25000,
#   'max_salary': None,
#   'currency_salary': 'руб.',
#   'link': 'https://hh.ru/vacancy/77232367?from=vacancy_search_list&query=python',
#   'source': 'hh.ru'},
#  {'name': 'Программист Python',
#   'salary': 'З/П не указана',
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'link': 'https://hh.ru/vacancy/77218092?from=vacancy_search_list&query=python',
#   'source': 'hh.ru'},
#  {'name': 'Преподаватель Python',
#   'salary': 'от 125\u202f000 руб.',
#   'min_salary': 125000,
#   'max_salary': None,
#   'currency_salary': 'руб.',
#   'link': 'https://hh.ru/vacancy/77083925?from=vacancy_search_list&query=python',
#   'source': 'hh.ru'},
#  {'name': 'Python developer',
#   'salary': 'З/П не указана',
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'link': 'https://hh.ru/vacancy/75574711?from=vacancy_search_list&query=python',
#   'source': 'hh.ru'},
#  {'name': 'Data/Product Analyst',
#   'salary': 'до 330\u202f000 руб.',
#   'min_salary': None,
#   'max_salary': 330000,
#   'currency_salary': 'руб.',
#   'link': 'https://hh.ru/vacancy/77206133?from=vacancy_search_list&query=python',
#   'source': 'hh.ru'},
#  {'name': 'Разработчик бэкенда на Python в Вертикали',
#   'salary': 'З/П не указана',
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'link': 'https://hh.ru/vacancy/76831393?from=vacancy_search_list&query=python',
#   'source': 'hh.ru'},
#  {'name': 'Ментор на курс Python',
#   'salary': 'З/П не указана',
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'link': 'https://hh.ru/vacancy/77259417?from=vacancy_search_list&query=python',
#   'source': 'hh.ru'},
#  {'name': 'Разработчик Python',
#   'salary': 'от 120\u202f000 руб.',
#   'min_salary': 120000,
#   'max_salary': None,
#   'currency_salary': 'руб.',
#   'link': 'https://hh.ru/vacancy/76076341?from=vacancy_search_list&query=python',
#   'source': 'hh.ru'},
#  {'name': 'Junior/Middle Backend-разработчик на Ruby',
#   'salary': '110\u202f000 – 150\u202f000 руб.',
#   'min_salary': 110000,
#   'max_salary': 150000,
#   'currency_salary': 'руб.',
#   'link': 'https://hh.ru/vacancy/76964796?from=vacancy_search_list&query=python',
#   'source': 'hh.ru'},
#  {'name': 'Разработчик Python',
#   'salary': 'от 150\u202f000 руб.',
#   'min_salary': 150000,
#   'max_salary': None,
#   'currency_salary': 'руб.',
#   'link': 'https://hh.ru/vacancy/76433537?from=vacancy_search_list&query=python',
#   'source': 'hh.ru'},
#  {'name': 'Аналитик данных / Data Analyst',
#   'salary': '80\u202f000 – 120\u202f000 руб.',
#   'min_salary': 80000,
#   'max_salary': 120000,
#   'currency_salary': 'руб.',
#   'link': 'https://hh.ru/vacancy/77024983?from=vacancy_search_list&query=python',
#   'source': 'hh.ru'},
#  {'name': 'AI / ML Specialist',
#   'salary': 'З/П не указана',
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'link': 'https://hh.ru/vacancy/77185485?from=vacancy_search_list&query=python',
#   'source': 'hh.ru'},
#  {'name': 'Python Data Engineer (junior)',
#   'salary': 'З/П не указана',
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'link': 'https://hh.ru/vacancy/76141435?from=vacancy_search_list&query=python',
#   'source': 'hh.ru'},
#  {'name': 'Python developer (remote)',
#   'salary': 'от 1\u202f000 USD',
#   'min_salary': 1000,
#   'max_salary': None,
#   'currency_salary': 'USD',
#   'link': 'https://hh.ru/vacancy/77245811?from=vacancy_search_list&query=python',
#   'source': 'hh.ru'},
#  {'name': 'Разработчик Python',
#   'salary': 'от 200\u202f000 руб.',
#   'min_salary': 200000,
#   'max_salary': None,
#   'currency_salary': 'руб.',
#   'link': 'https://hh.ru/vacancy/77089579?from=vacancy_search_list&query=python',
#   'source': 'hh.ru'},
#  {'name': 'Python Web Developer',
#   'salary': 'З/П не указана',
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'link': 'https://hh.ru/vacancy/75771778?from=vacancy_search_list&query=python',
#   'source': 'hh.ru'},
#  {'name': 'Artificial Intelligence / Machine Learning Engineer',
#   'salary': 'З/П не указана',
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'link': 'https://hh.ru/vacancy/77351702?from=vacancy_search_list&query=python',
#   'source': 'hh.ru'},
#  {'name': 'С++ Developer (Python)',
#   'salary': 'от 150\u202f000 руб.',
#   'min_salary': 150000,
#   'max_salary': None,
#   'currency_salary': 'руб.',
#   'link': 'https://hh.ru/vacancy/73030684?from=vacancy_search_list&query=python',
#   'source': 'hh.ru'},
#  {'name': 'Backend программист (Python)',
#   'salary': 'от 120\u202f000 руб.',
#   'min_salary': 120000,
#   'max_salary': None,
#   'currency_salary': 'руб.',
#   'link': 'https://hh.ru/vacancy/77147428?from=vacancy_search_list&query=python',
#   'source': 'hh.ru'},
#  {'name': 'Разработчик Python и SQL',
#   'salary': 'от 60\u202f000 руб.',
#   'min_salary': 60000,
#   'max_salary': None,
#   'currency_salary': 'руб.',
#   'link': 'https://hh.ru/vacancy/76425036?from=vacancy_search_list&query=python',
#   'source': 'hh.ru'},
#  {'name': 'Python-разработчик систем сбора',
#   'salary': '100\u202f000 – 150\u202f000 руб.',
#   'min_salary': 100000,
#   'max_salary': 150000,
#   'currency_salary': 'руб.',
#   'link': 'https://hh.ru/vacancy/72687495?from=vacancy_search_list&query=python',
#   'source': 'hh.ru'},
#  {'name': 'Middle Python-разработчик',
#   'salary': '140\u202f000 – 250\u202f000 руб.',
#   'min_salary': 140000,
#   'max_salary': 250000,
#   'currency_salary': 'руб.',
#   'link': 'https://hh.ru/vacancy/75679088?from=vacancy_search_list&query=python',
#   'source': 'hh.ru'},
#  {'name': 'Стажер-аналитик',
#   'salary': 'З/П не указана',
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'link': 'https://hh.ru/vacancy/77306960?from=vacancy_search_list&query=python',
#   'source': 'hh.ru'},
#  {'name': 'Middle Python/Go developer',
#   'salary': 'от 150\u202f000 руб.',
#   'min_salary': 150000,
#   'max_salary': None,
#   'currency_salary': 'руб.',
#   'link': 'https://hh.ru/vacancy/77230563?from=vacancy_search_list&query=python',
#   'source': 'hh.ru'},
#  {'name': 'Программист-разработчик',
#   'salary': 'З/П не указана',
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'link': 'https://hh.ru/vacancy/76762046?from=vacancy_search_list&query=python',
#   'source': 'hh.ru'},
#  {'name': 'Full-stack Python/Django-разработчик',
#   'salary': 'до 200\u202f000 руб.',
#   'min_salary': None,
#   'max_salary': 200000,
#   'currency_salary': 'руб.',
#   'link': 'https://hh.ru/vacancy/76549392?from=vacancy_search_list&query=python',
#   'source': 'hh.ru'},
#  {'name': 'Аналитик данных (Data Analist)',
#   'salary': 'З/П не указана',
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'link': 'https://hh.ru/vacancy/76584671?from=vacancy_search_list&query=python',
#   'source': 'hh.ru'},
#  {'name': 'Python Developer',
#   'salary': 'З/П не указана',
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'link': 'https://hh.ru/vacancy/76843829?from=vacancy_search_list&query=python',
#   'source': 'hh.ru'},
#  {'name': 'Middle Python developer',
#   'salary': '120\u202f000 – 200\u202f000 руб.',
#   'min_salary': 120000,
#   'max_salary': 200000,
#   'currency_salary': 'руб.',
#   'link': 'https://hh.ru/vacancy/76595028?from=vacancy_search_list&query=python',
#   'source': 'hh.ru'},
#  {'name': 'Data Scientist CVM',
#   'salary': 'З/П не указана',
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'link': 'https://hh.ru/vacancy/77366229?from=vacancy_search_list&query=python',
#   'source': 'hh.ru'},
#  {'name': 'Senior Python Developer (Беспилотные автомобили)',
#   'salary': 'З/П не указана',
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'link': 'https://hh.ru/vacancy/76985818?from=vacancy_search_list&query=python',
#   'source': 'hh.ru'},
#  {'name': 'Преподаватель Python',
#   'salary': 'от 125\u202f000 руб.',
#   'min_salary': 125000,
#   'max_salary': None,
#   'currency_salary': 'руб.',
#   'link': 'https://hh.ru/vacancy/77083926?from=vacancy_search_list&query=python',
#   'source': 'hh.ru'},
#  {'name': 'Backend-разработчик Python/Django',
#   'salary': 'З/П не указана',
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'link': 'https://hh.ru/vacancy/75850366?from=vacancy_search_list&query=python',
#   'source': 'hh.ru'},
#  {'name': 'Python / Go Разработчик',
#   'salary': 'З/П не указана',
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'link': 'https://hh.ru/vacancy/74089202?from=vacancy_search_list&query=python',
#   'source': 'hh.ru'},
#  {'name': 'Программист Python',
#   'salary': 'З/П не указана',
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'link': 'https://hh.ru/vacancy/75704098?from=vacancy_search_list&query=python',
#   'source': 'hh.ru'},
#  {'name': 'DevOps инженер',
#   'salary': '100\u202f000 – 120\u202f000 руб.',
#   'min_salary': 100000,
#   'max_salary': 120000,
#   'currency_salary': 'руб.',
#   'link': 'https://hh.ru/vacancy/76587347?from=vacancy_search_list&query=python',
#   'source': 'hh.ru'},
#  {'name': 'Lead Backend Developer (python)',
#   'salary': 'от 200\u202f000 руб.',
#   'min_salary': 200000,
#   'max_salary': None,
#   'currency_salary': 'руб.',
#   'link': 'https://hh.ru/vacancy/76971118?from=vacancy_search_list&query=python',
#   'source': 'hh.ru'},
#  {'name': 'Data analyst / Аналитик данных',
#   'salary': 'от 90\u202f000 руб.',
#   'min_salary': 90000,
#   'max_salary': None,
#   'currency_salary': 'руб.',
#   'link': 'https://hh.ru/vacancy/76690668?from=vacancy_search_list&query=python',
#   'source': 'hh.ru'},
#  {'name': 'Senior Python developer (Django)',
#   'salary': 'до 450\u202f000 руб.',
#   'min_salary': None,
#   'max_salary': 450000,
#   'currency_salary': 'руб.',
#   'link': 'https://hh.ru/vacancy/76821520?from=vacancy_search_list&query=python',
#   'source': 'hh.ru'},
#  {'name': 'Инженер данных ClickHouse',
#   'salary': '120\u202f000 – 200\u202f000 руб.',
#   'min_salary': 120000,
#   'max_salary': 200000,
#   'currency_salary': 'руб.',
#   'link': 'https://hh.ru/vacancy/77225799?from=vacancy_search_list&query=python',
#   'source': 'hh.ru'},
#  {'name': 'Senior Python developer (Django)',
#   'salary': 'до 450\u202f000 руб.',
#   'min_salary': None,
#   'max_salary': 450000,
#   'currency_salary': 'руб.',
#   'link': 'https://hh.ru/vacancy/76821519?from=vacancy_search_list&query=python',
#   'source': 'hh.ru'},
#  {'name': 'Разработчик Python',
#   'salary': '80\u202f000 – 120\u202f000 руб.',
#   'min_salary': 80000,
#   'max_salary': 120000,
#   'currency_salary': 'руб.',
#   'link': 'https://hh.ru/vacancy/77038104?from=vacancy_search_list&query=python',
#   'source': 'hh.ru'},
#  {'name': 'Инженер-программист Python (автоматизация испытательных стендов)',
#   'salary': 'З/П не указана',
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'link': 'https://hh.ru/vacancy/76924233?from=vacancy_search_list&query=python',
#   'source': 'hh.ru'},
#  {'name': 'Deep Learning инженер',
#   'salary': 'З/П не указана',
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'link': 'https://hh.ru/vacancy/76752874?from=vacancy_search_list&query=python',
#   'source': 'hh.ru'},
#  {'name': 'Python developer',
#   'salary': '150\u202f000 – 250\u202f000 руб.',
#   'min_salary': 150000,
#   'max_salary': 250000,
#   'currency_salary': 'руб.',
#   'link': 'https://hh.ru/vacancy/46229759?from=vacancy_search_list&query=python',
#   'source': 'hh.ru'},
#  {'name': 'Middle / Middle+ Python (Django) developer',
#   'salary': 'З/П не указана',
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'link': 'https://hh.ru/vacancy/76541749?from=vacancy_search_list&query=python',
#   'source': 'hh.ru'},
#  {'name': 'Программист Python - FastAPI',
#   'salary': 'от 180\u202f000 руб.',
#   'min_salary': 180000,
#   'max_salary': None,
#   'currency_salary': 'руб.',
#   'link': 'https://hh.ru/vacancy/77096692?from=vacancy_search_list&query=python',
#   'source': 'hh.ru'},
#  {'name': 'Программист Python',
#   'salary': 'З/П не указана',
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'link': 'https://hh.ru/vacancy/77065085?from=vacancy_search_list&query=python',
#   'source': 'hh.ru'},
#  {'name': 'Python developer',
#   'salary': 'З/П не указана',
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'link': 'https://hh.ru/vacancy/76544211?from=vacancy_search_list&query=python',
#   'source': 'hh.ru'},
#  {'name': 'Python developer (middle/senior) удаленно',
#   'salary': 'З/П не указана',
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'link': 'https://hh.ru/vacancy/77321723?from=vacancy_search_list&query=python',
#   'source': 'hh.ru'},
#  {'name': 'Data Scientist/python-разработчик',
#   'salary': 'З/П не указана',
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'link': 'https://hh.ru/vacancy/77107666?from=vacancy_search_list&query=python',
#   'source': 'hh.ru'},
#  {'name': 'Программист Python - FastAPI',
#   'salary': 'от 180\u202f000 руб.',
#   'min_salary': 180000,
#   'max_salary': None,
#   'currency_salary': 'руб.',
#   'link': 'https://hh.ru/vacancy/77096615?from=vacancy_search_list&query=python',
#   'source': 'hh.ru'},
#  {'name': 'Python senior developer (разработчик)',
#   'salary': 'от 250\u202f000 руб.',
#   'min_salary': 250000,
#   'max_salary': None,
#   'currency_salary': 'руб.',
#   'link': 'https://hh.ru/vacancy/76840139?from=vacancy_search_list&query=python',
#   'source': 'hh.ru'},
#  {'name': 'Python-разработчик (Middle)',
#   'salary': 'до 240\u202f000 руб.',
#   'min_salary': None,
#   'max_salary': 240000,
#   'currency_salary': 'руб.',
#   'link': 'https://hh.ru/vacancy/77276110?from=vacancy_search_list&query=python',
#   'source': 'hh.ru'},
#  {'name': 'Middle / Middle+ Python Developer (backend)',
#   'salary': '200\u202f000 – 300\u202f000 руб.',
#   'min_salary': 200000,
#   'max_salary': 300000,
#   'currency_salary': 'руб.',
#   'link': 'https://hh.ru/vacancy/77073241?from=vacancy_search_list&query=python',
#   'source': 'hh.ru'},
#  {'name': 'Системный аналитик (аналитик-разработчик)',
#   'salary': '130\u202f000 – 230\u202f000 руб.',
#   'min_salary': 130000,
#   'max_salary': 230000,
#   'currency_salary': 'руб.',
#   'link': 'https://hh.ru/vacancy/76732634?from=vacancy_search_list&query=python',
#   'source': 'hh.ru'},
#  {'name': 'Middle Python Developer (Backend / Server side)',
#   'salary': '140\u202f000 – 220\u202f000 руб.',
#   'min_salary': 140000,
#   'max_salary': 220000,
#   'currency_salary': 'руб.',
#   'link': 'https://hh.ru/vacancy/77148120?from=vacancy_search_list&query=python',
#   'source': 'hh.ru'},
#  {'name': 'QA Engineer на мобильную RTS',
#   'salary': 'З/П не указана',
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'link': 'https://hh.ru/vacancy/73576354?from=vacancy_search_list&query=python',
#   'source': 'hh.ru'},
#  {'name': 'Эконометрист/Data scientist (Junior/Middle) в консалтинг',
#   'salary': 'от 40\u202f000 руб.',
#   'min_salary': 40000,
#   'max_salary': None,
#   'currency_salary': 'руб.',
#   'link': 'https://hh.ru/vacancy/75546364?from=vacancy_search_list&query=python',
#   'source': 'hh.ru'},
#  {'name': 'Python Back-end Разработчик / Python Back-end Developer',
#   'salary': 'З/П не указана',
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'link': 'https://hh.ru/vacancy/46823861?from=vacancy_search_list&query=python',
#   'source': 'hh.ru'},
#  {'name': 'Python разработчик',
#   'salary': 'З/П не указана',
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'link': 'https://hh.ru/vacancy/77075044?from=vacancy_search_list&query=python',
#   'source': 'hh.ru'},
#  {'name': 'BackEnd Developer (Python)',
#   'salary': 'З/П не указана',
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'link': 'https://hh.ru/vacancy/77264154?from=vacancy_search_list&query=python',
#   'source': 'hh.ru'},
#  {'name': 'Преподаватель по программированию для детей и подростков',
#   'salary': '250\u202f000 – 300\u202f000 KZT',
#   'min_salary': 250000,
#   'max_salary': 300000,
#   'currency_salary': 'KZT',
#   'link': 'https://hh.ru/vacancy/77037685?from=vacancy_search_list&query=python',
#   'source': 'hh.ru'},
#  {'name': 'Python программист (Наставник онлайн-курса по Python)',
#   'salary': 'до 80\u202f000 руб.',
#   'min_salary': None,
#   'max_salary': 80000,
#   'currency_salary': 'руб.',
#   'link': 'https://hh.ru/vacancy/67864415?from=vacancy_search_list&query=python',
#   'source': 'hh.ru'},
#  {'name': 'Младший аналитик',
#   'salary': 'З/П не указана',
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'link': 'https://hh.ru/vacancy/76921964?from=vacancy_search_list&query=python',
#   'source': 'hh.ru'},
#  {'name': 'Python разработчик',
#   'salary': 'от 350\u202f000 руб.',
#   'min_salary': 350000,
#   'max_salary': None,
#   'currency_salary': 'руб.',
#   'link': 'https://hh.ru/vacancy/76929580?from=vacancy_search_list&query=python',
#   'source': 'hh.ru'},
#  {'name': 'Middle Python Developer (Machine Learning)',
#   'salary': 'З/П не указана',
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'link': 'https://hh.ru/vacancy/77342523?from=vacancy_search_list&query=python',
#   'source': 'hh.ru'},
#  {'name': 'Разработчик Python+MS SQL+1C',
#   'salary': 'З/П не указана',
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'link': 'https://hh.ru/vacancy/75878225?from=vacancy_search_list&query=python',
#   'source': 'hh.ru'},
#  {'name': 'Разработчик Python (ALD)',
#   'salary': 'З/П не указана',
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'link': 'https://hh.ru/vacancy/70052938?from=vacancy_search_list&query=python',
#   'source': 'hh.ru'},
#  {'name': 'Team Lead with back-end (Python) - remote',
#   'salary': '4\u202f000 – 5\u202f000 USD',
#   'min_salary': 4000,
#   'max_salary': 5000,
#   'currency_salary': 'USD',
#   'link': 'https://hh.ru/vacancy/77363153?from=vacancy_search_list&query=python',
#   'source': 'hh.ru'},
#  {'name': 'Инженер-программист / Бэкенд-разработчик на Python',
#   'salary': 'от 50\u202f000 руб.',
#   'min_salary': 50000,
#   'max_salary': None,
#   'currency_salary': 'руб.',
#   'link': 'https://hh.ru/vacancy/70975727?from=vacancy_search_list&query=python',
#   'source': 'hh.ru'},
#  {'name': 'Middle/senior python разработчик',
#   'salary': 'от 200\u202f000 руб.',
#   'min_salary': 200000,
#   'max_salary': None,
#   'currency_salary': 'руб.',
#   'link': 'https://hh.ru/vacancy/76712283?from=vacancy_search_list&query=python',
#   'source': 'hh.ru'},
#  {'name': 'Data-analyst',
#   'salary': 'З/П не указана',
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'link': 'https://hh.ru/vacancy/76417646?from=vacancy_search_list&query=python',
#   'source': 'hh.ru'},
#  {'name': 'Data analyst / Аналитик данных',
#   'salary': 'З/П не указана',
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'link': 'https://hh.ru/vacancy/73591237?from=vacancy_search_list&query=python',
#   'source': 'hh.ru'},
#  {'name': 'Senior Python developer',
#   'salary': 'от 230\u202f000 руб.',
#   'min_salary': 230000,
#   'max_salary': None,
#   'currency_salary': 'руб.',
#   'link': 'https://hh.ru/vacancy/75859273?from=vacancy_search_list&query=python',
#   'source': 'hh.ru'},
#  {'name': 'Инженер по автоматизации тестирования Python',
#   'salary': 'З/П не указана',
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'link': 'https://hh.ru/vacancy/77332335?from=vacancy_search_list&query=python',
#   'source': 'hh.ru'},
#  {'name': 'Data Analyst / Аналитик Bl',
#   'salary': 'до 140\u202f000 руб.',
#   'min_salary': None,
#   'max_salary': 140000,
#   'currency_salary': 'руб.',
#   'link': 'https://hh.ru/vacancy/76348422?from=vacancy_search_list&query=python',
#   'source': 'hh.ru'},
#  {'name': 'Middle Python разработчик',
#   'salary': '120\u202f000 – 180\u202f000 руб.',
#   'min_salary': 120000,
#   'max_salary': 180000,
#   'currency_salary': 'руб.',
#   'link': 'https://hh.ru/vacancy/77019389?from=vacancy_search_list&query=python',
#   'source': 'hh.ru'},
#  {'name': 'Strong Middle Python developer',
#   'salary': 'З/П не указана',
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'link': 'https://hh.ru/vacancy/77218819?from=vacancy_search_list&query=python',
#   'source': 'hh.ru'},
#  {'name': 'Python senior developer (разработчик)',
#   'salary': 'от 250\u202f000 руб.',
#   'min_salary': 250000,
#   'max_salary': None,
#   'currency_salary': 'руб.',
#   'link': 'https://hh.ru/vacancy/76840138?from=vacancy_search_list&query=python',
#   'source': 'hh.ru'},
#  {'name': 'Middle backend-разработчик Python',
#   'salary': 'З/П не указана',
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'link': 'https://hh.ru/vacancy/76140465?from=vacancy_search_list&query=python',
#   'source': 'hh.ru'},
#  {'name': 'Game Analyst (игровой аналитик)',
#   'salary': 'З/П не указана',
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'link': 'https://hh.ru/vacancy/76254367?from=vacancy_search_list&query=python',
#   'source': 'hh.ru'},
#  {'name': 'Ведущий разработчик Python',
#   'salary': 'З/П не указана',
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'link': 'https://hh.ru/vacancy/72399179?from=vacancy_search_list&query=python',
#   'source': 'hh.ru'},
#  {'name': 'Программист Linux',
#   'salary': '100\u202f000 – 500\u202f000 руб.',
#   'min_salary': 100000,
#   'max_salary': 500000,
#   'currency_salary': 'руб.',
#   'link': 'https://hh.ru/vacancy/76592132?from=vacancy_search_list&query=python',
#   'source': 'hh.ru'},
#  {'name': 'Python Backend Developer (middle)',
#   'salary': 'З/П не указана',
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'link': 'https://hh.ru/vacancy/76924747?from=vacancy_search_list&query=python',
#   'source': 'hh.ru'},
#  {'name': 'Middle backend developer',
#   'salary': 'от 500\u202f000 KZT',
#   'min_salary': 500000,
#   'max_salary': None,
#   'currency_salary': 'KZT',
#   'link': 'https://hh.ru/vacancy/77367992?from=vacancy_search_list&query=python',
#   'source': 'hh.ru'},
#  {'name': 'Менеджер проектов со знанием Python',
#   'salary': '30\u202f000 – 50\u202f000 руб.',
#   'min_salary': 30000,
#   'max_salary': 50000,
#   'currency_salary': 'руб.',
#   'link': 'https://hh.ru/vacancy/77148210?from=vacancy_search_list&query=python',
#   'source': 'hh.ru'},
#  {'name': 'Senior Python Developer',
#   'salary': '5\u202f000 – 6\u202f000 USD',
#   'min_salary': 5000,
#   'max_salary': 6000,
#   'currency_salary': 'USD',
#   'link': 'https://hh.ru/vacancy/76650700?from=vacancy_search_list&query=python',
#   'source': 'hh.ru'},
#  {'name': 'Главный разработчик Python',
#   'salary': '100\u202f000 – 200\u202f000 руб.',
#   'min_salary': 100000,
#   'max_salary': 200000,
#   'currency_salary': 'руб.',
#   'link': 'https://hh.ru/vacancy/70093763?from=vacancy_search_list&query=python',
#   'source': 'hh.ru'},
#  {'name': 'Младший преподаватель Python (Физтехпарк)',
#   'salary': 'З/П не указана',
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'link': 'https://hh.ru/vacancy/75729936?from=vacancy_search_list&query=python',
#   'source': 'hh.ru'},
#  {'name': 'Аналитик данных',
#   'salary': 'З/П не указана',
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'link': 'https://hh.ru/vacancy/77219984?from=vacancy_search_list&query=python',
#   'source': 'hh.ru'},
#  {'name': 'Программист Python php (Москва)',
#   'salary': '80\u202f000 – 100\u202f000 руб.',
#   'min_salary': 80000,
#   'max_salary': 100000,
#   'currency_salary': 'руб.',
#   'link': 'https://hh.ru/vacancy/77163195?from=vacancy_search_list&query=python',
#   'source': 'hh.ru'},
#  {'name': 'Программист qlikview',
#   'salary': 'З/П не указана',
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'link': 'https://hh.ru/vacancy/77285800?from=vacancy_search_list&query=python',
#   'source': 'hh.ru'},
#  {'name': 'Data scientist / Аналитик риск-моделей',
#   'salary': '120\u202f000 – 300\u202f000 руб.',
#   'min_salary': 120000,
#   'max_salary': 300000,
#   'currency_salary': 'руб.',
#   'link': 'https://hh.ru/vacancy/77181469?from=vacancy_search_list&query=python',
#   'source': 'hh.ru'},
#  {'name': 'Python Developer',
#   'salary': 'З/П не указана',
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'link': 'https://hh.ru/vacancy/77220983?from=vacancy_search_list&query=python',
#   'source': 'hh.ru'},
#  {'name': 'Инженер по применению (направление "Искусственный интеллект")',
#   'salary': 'З/П не указана',
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'link': 'https://hh.ru/vacancy/76371806?from=vacancy_search_list&query=python',
#   'source': 'hh.ru'},
#  {'name': 'Разработчик Python',
#   'salary': 'З/П не указана',
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'link': 'https://hh.ru/vacancy/51472686?from=vacancy_search_list&query=python',
#   'source': 'hh.ru'},
#  {'name': 'Team Lead Python',
#   'salary': 'от 6\u202f500 USD',
#   'min_salary': 6500,
#   'max_salary': None,
#   'currency_salary': 'USD',
#   'link': 'https://hh.ru/vacancy/69431361?from=vacancy_search_list&query=python',
#   'source': 'hh.ru'},
#  {'name': 'Middle Python Developer',
#   'salary': 'З/П не указана',
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'link': 'https://hh.ru/vacancy/76112746?from=vacancy_search_list&query=python',
#   'source': 'hh.ru'},
#  {'name': 'Middle Backend Developer',
#   'salary': '100\u202f000 – 130\u202f000 руб.',
#   'min_salary': 100000,
#   'max_salary': 130000,
#   'currency_salary': 'руб.',
#   'link': 'https://hh.ru/vacancy/76716623?from=vacancy_search_list&query=python',
#   'source': 'hh.ru'},
#  {'name': 'Python-разработчик',
#   'salary': 'З/П не указана',
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'link': 'https://hh.ru/vacancy/77032460?from=vacancy_search_list&query=python',
#   'source': 'hh.ru'},
#  {'name': 'Системный аналитик',
#   'salary': 'от 180\u202f000 руб.',
#   'min_salary': 180000,
#   'max_salary': None,
#   'currency_salary': 'руб.',
#   'link': 'https://hh.ru/vacancy/76825827?from=vacancy_search_list&query=python',
#   'source': 'hh.ru'},
#  {'name': 'Программист Python',
#   'salary': 'З/П не указана',
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'link': 'https://hh.ru/vacancy/67711604?from=vacancy_search_list&query=python',
#   'source': 'hh.ru'},
#  {'name': 'Наставник курсов по Python разработке',
#   'salary': '40\u202f000 – 80\u202f000 руб.',
#   'min_salary': 40000,
#   'max_salary': 80000,
#   'currency_salary': 'руб.',
#   'link': 'https://hh.ru/vacancy/77349366?from=vacancy_search_list&query=python',
#   'source': 'hh.ru'},
#  {'name': 'Продуктовый аналитик/Product Analyst',
#   'salary': 'от 150\u202f000 руб.',
#   'min_salary': 150000,
#   'max_salary': None,
#   'currency_salary': 'руб.',
#   'link': 'https://hh.ru/vacancy/77218483?from=vacancy_search_list&query=python',
#   'source': 'hh.ru'},
#  {'name': 'Разработчик Python (middle)',
#   'salary': 'З/П не указана',
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'link': 'https://hh.ru/vacancy/76816845?from=vacancy_search_list&query=python',
#   'source': 'hh.ru'},
#  {'name': 'Backend разработчик (Python)',
#   'salary': 'от 150\u202f000 руб.',
#   'min_salary': 150000,
#   'max_salary': None,
#   'currency_salary': 'руб.',
#   'link': 'https://hh.ru/vacancy/76891919?from=vacancy_search_list&query=python',
#   'source': 'hh.ru'},
#  {'name': 'Python Backend Developer (Senior/Remote)',
#   'salary': 'до 300\u202f000 руб.',
#   'min_salary': None,
#   'max_salary': 300000,
#   'currency_salary': 'руб.',
#   'link': 'https://hh.ru/vacancy/77060239?from=vacancy_search_list&query=python',
#   'source': 'hh.ru'},
#  {'name': 'Python-разработчик (команда SberWorks)',
#   'salary': 'З/П не указана',
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'link': 'https://hh.ru/vacancy/77133306?from=vacancy_search_list&query=python',
#   'source': 'hh.ru'},
#  {'name': 'Разработчик интеграционных решений',
#   'salary': 'З/П не указана',
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'link': 'https://hh.ru/vacancy/76110611?from=vacancy_search_list&query=python',
#   'source': 'hh.ru'},
#  {'name': 'C++ Developer (MetaTrader)',
#   'salary': 'до 200\u202f000 руб.',
#   'min_salary': None,
#   'max_salary': 200000,
#   'currency_salary': 'руб.',
#   'link': 'https://hh.ru/vacancy/77232587?from=vacancy_search_list&query=python',
#   'source': 'hh.ru'},
#  {'name': 'Middle/Senior bakend разработчик (Python)',
#   'salary': 'З/П не указана',
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'link': 'https://hh.ru/vacancy/75977451?from=vacancy_search_list&query=python',
#   'source': 'hh.ru'},
#  {'name': 'Python-разработчик',
#   'salary': 'З/П не указана',
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'link': 'https://hh.ru/vacancy/77030437?from=vacancy_search_list&query=python',
#   'source': 'hh.ru'},
#  {'name': 'Python-разработчик (Senior)',
#   'salary': 'от 240\u202f000 руб.',
#   'min_salary': 240000,
#   'max_salary': None,
#   'currency_salary': 'руб.',
#   'link': 'https://hh.ru/vacancy/77331406?from=vacancy_search_list&query=python',
#   'source': 'hh.ru'},
#  {'name': 'Fullstack Разработчик',
#   'salary': 'от 50\u202f000 руб.',
#   'min_salary': 50000,
#   'max_salary': None,
#   'currency_salary': 'руб.',
#   'link': 'https://hh.ru/vacancy/77266384?from=vacancy_search_list&query=python',
#   'source': 'hh.ru'},
#  {'name': 'Главный python разработчик управления данными (ДПП)',
#   'salary': 'З/П не указана',
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'link': 'https://hh.ru/vacancy/76080775?from=vacancy_search_list&query=python',
#   'source': 'hh.ru'},
#  {'name': 'Python-разработчик (middle)',
#   'salary': 'З/П не указана',
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'link': 'https://hh.ru/vacancy/77289629?from=vacancy_search_list&query=python',
#   'source': 'hh.ru'},
#  {'name': 'Data-аналитик',
#   'salary': 'З/П не указана',
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'link': 'https://hh.ru/vacancy/76933775?from=vacancy_search_list&query=python',
#   'source': 'hh.ru'},
#  {'name': 'Python (опыт с Rust) разработчик (PT Sandbox)',
#   'salary': 'З/П не указана',
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'link': 'https://hh.ru/vacancy/76916725?from=vacancy_search_list&query=python',
#   'source': 'hh.ru'},
#  {'name': 'Python разработчик',
#   'salary': 'З/П не указана',
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'link': 'https://hh.ru/vacancy/76780632?from=vacancy_search_list&query=python',
#   'source': 'hh.ru'},
#  {'name': 'Python разработчик (проект Лаборатория измерительных систем)',
#   'salary': 'З/П не указана',
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'link': 'https://hh.ru/vacancy/77193986?from=vacancy_search_list&query=python',
#   'source': 'hh.ru'},
#  {'name': 'Разработчик базы данных',
#   'salary': 'З/П не указана',
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'link': 'https://hh.ru/vacancy/75522993?from=vacancy_search_list&query=python',
#   'source': 'hh.ru'},
#  {'name': 'Программист-разработчик компьютерного зрения (python)',
#   'salary': 'З/П не указана',
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'link': 'https://hh.ru/vacancy/77002334?from=vacancy_search_list&query=python',
#   'source': 'hh.ru'},
#  {'name': 'Python разработчик Junior',
#   'salary': '40\u202f000 – 60\u202f000 руб.',
#   'min_salary': 40000,
#   'max_salary': 60000,
#   'currency_salary': 'руб.',
#   'link': 'https://hh.ru/vacancy/76757250?from=vacancy_search_list&query=python',
#   'source': 'hh.ru'},
#  {'name': 'Software Engineer in Test (Python)',
#   'salary': 'З/П не указана',
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'link': 'https://hh.ru/vacancy/74803836?from=vacancy_search_list&query=python',
#   'source': 'hh.ru'},
#  {'name': 'Программист-разработчик',
#   'salary': 'от 85\u202f000 руб.',
#   'min_salary': 85000,
#   'max_salary': None,
#   'currency_salary': 'руб.',
#   'link': 'https://hh.ru/vacancy/77192679?from=vacancy_search_list&query=python',
#   'source': 'hh.ru'},
#  {'name': 'Python Team Lead',
#   'salary': 'З/П не указана',
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'link': 'https://hh.ru/vacancy/76707495?from=vacancy_search_list&query=python',
#   'source': 'hh.ru'},
#  {'name': 'Middle OpenStack Python',
#   'salary': 'З/П не указана',
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'link': 'https://hh.ru/vacancy/75726638?from=vacancy_search_list&query=python',
#   'source': 'hh.ru'},
#  {'name': 'Программист',
#   'salary': 'З/П не указана',
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'link': 'https://hh.ru/vacancy/76800949?from=vacancy_search_list&query=python',
#   'source': 'hh.ru'},
#  {'name': 'Data Engineer',
#   'salary': 'З/П не указана',
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'link': 'https://hh.ru/vacancy/76068416?from=vacancy_search_list&query=python',
#   'source': 'hh.ru'},
#  {'name': 'Программист/разработчик Linux',
#   'salary': 'от 200\u202f000 руб.',
#   'min_salary': 200000,
#   'max_salary': None,
#   'currency_salary': 'руб.',
#   'link': 'https://hh.ru/vacancy/76676691?from=vacancy_search_list&query=python',
#   'source': 'hh.ru'},
#  {'name': 'Стажер Sberseasons осень 2022 Data Science Новосибирск',
#   'salary': 'З/П не указана',
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'link': 'https://hh.ru/vacancy/77053286?from=vacancy_search_list&query=python',
#   'source': 'hh.ru'},
#  {'name': 'Junior Data Analyst',
#   'salary': 'З/П не указана',
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'link': 'https://hh.ru/vacancy/76902009?from=vacancy_search_list&query=python',
#   'source': 'hh.ru'},
#  {'name': 'Программист Linux',
#   'salary': '100\u202f000 – 500\u202f000 руб.',
#   'min_salary': 100000,
#   'max_salary': 500000,
#   'currency_salary': 'руб.',
#   'link': 'https://hh.ru/vacancy/76592132?from=vacancy_search_list&query=python',
#   'source': 'hh.ru'},
#  {'name': 'Web-программист (удаленно)',
#   'salary': 'от 40\u202f000 руб.',
#   'min_salary': 40000,
#   'max_salary': None,
#   'currency_salary': 'руб.',
#   'link': 'https://hh.ru/vacancy/77388672?from=vacancy_search_list&query=python',
#   'source': 'hh.ru'},
#  {'name': 'Sr Python разработчик (удаленно)',
#   'salary': 'до 300\u202f000 руб.',
#   'min_salary': None,
#   'max_salary': 300000,
#   'currency_salary': 'руб.',
#   'link': 'https://hh.ru/vacancy/76958513?from=vacancy_search_list&query=python',
#   'source': 'hh.ru'},
#  {'name': 'Middle Python developer',
#   'salary': 'З/П не указана',
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'link': 'https://hh.ru/vacancy/77301956?from=vacancy_search_list&query=python',
#   'source': 'hh.ru'},
#  {'name': 'Аналитик DWH (junior)',
#   'salary': 'З/П не указана',
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'link': 'https://hh.ru/vacancy/76202621?from=vacancy_search_list&query=python',
#   'source': 'hh.ru'},
#  {'name': 'Тестировщик на Python',
#   'salary': 'З/П не указана',
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'link': 'https://hh.ru/vacancy/76324043?from=vacancy_search_list&query=python',
#   'source': 'hh.ru'},
#  {'name': 'Mid/Mid+ Data Scientist',
#   'salary': 'З/П не указана',
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'link': 'https://hh.ru/vacancy/76396688?from=vacancy_search_list&query=python',
# ...
#   'source': 'hh.ru'},
#  {'name': 'Программист API/API Developer',
#   'salary': 'З/П не указана',
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'link': 'https://hh.ru/vacancy/77280332?from=vacancy_search_list&query=python',
#   'source': 'hh.ru'},
#  {'name': 'Rust Developer',
#   'salary': 'от 2\u202f000 EUR',
#   'min_salary': 2000,
#   'max_salary': None,
#   'currency_salary': 'EUR',
#   'link': 'https://hh.ru/vacancy/77199590?from=vacancy_search_list&query=python',
#   'source': 'hh.ru'},
#  {'name': 'Сетевой инженер-программист',
#   'salary': 'от 160\u202f000 руб.',
#   'min_salary': 160000,
#   'max_salary': None,
#   'currency_salary': 'руб.',
#   'link': 'https://hh.ru/vacancy/77279011?from=vacancy_search_list&query=python',
#   'source': 'hh.ru'},
#  {'name': 'QA automation engineer',
#   'salary': 'от 120\u202f000 руб.',
#   'min_salary': 120000,
#   'max_salary': None,
#   'currency_salary': 'руб.',
#   'link': 'https://hh.ru/vacancy/77215426?from=vacancy_search_list&query=python',
#   'source': 'hh.ru'},
#  {'name': 'Machine learning engineer (проект "Группы")',
#   'salary': 'З/П не указана',
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'link': 'https://hh.ru/vacancy/68447647?from=vacancy_search_list&query=python',
#   'source': 'hh.ru'},
#  {'name': 'Senior Python Developer / Data Engineer в команду Data Catalog, платформа ML Space',
#   'salary': 'З/П не указана',
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'link': 'https://hh.ru/vacancy/71902418?from=vacancy_search_list&query=python',
#   'source': 'hh.ru'},
#  {'name': 'QA Automation Engineer',
#   'salary': 'З/П не указана',
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'link': 'https://hh.ru/vacancy/74803721?from=vacancy_search_list&query=python',
#   'source': 'hh.ru'},
#  {'name': 'Data Engineer в Практикум',
#   'salary': 'З/П не указана',
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'link': 'https://hh.ru/vacancy/77037098?from=vacancy_search_list&query=python',
#   'source': 'hh.ru'},
#  {'name': 'Machine learning engineer (проект "Группы")',
#   'salary': 'З/П не указана',
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'link': 'https://hh.ru/vacancy/68447646?from=vacancy_search_list&query=python',
#   'source': 'hh.ru'},
#  {'name': 'Инженер по нагрузочному тестированию',
#   'salary': 'З/П не указана',
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'link': 'https://hh.ru/vacancy/76558448?from=vacancy_search_list&query=python',
#   'source': 'hh.ru'},
#  {'name': 'Инженер-разработчик Data Science (проект "Лента")',
#   'salary': 'З/П не указана',
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'link': 'https://hh.ru/vacancy/48788339?from=vacancy_search_list&query=python',
#   'source': 'hh.ru'},
#  {'name': 'Senior Data Scientist',
#   'salary': 'З/П не указана',
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'link': 'https://hh.ru/vacancy/76333170?from=vacancy_search_list&query=python',
#   'source': 'hh.ru'},
#  {'name': 'Аналитик-разработчик',
#   'salary': 'З/П не указана',
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'link': 'https://hh.ru/vacancy/76519651?from=vacancy_search_list&query=python',
#   'source': 'hh.ru'},
#  {'name': 'Разработчик C (удаленная работа)',
#   'salary': 'до 350\u202f000 руб.',
#   'min_salary': None,
#   'max_salary': 350000,
#   'currency_salary': 'руб.',
#   'link': 'https://hh.ru/vacancy/76397262?from=vacancy_search_list&query=python',
#   'source': 'hh.ru'},
#  {'name': 'Data Engineer',
#   'salary': 'З/П не указана',
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'link': 'https://hh.ru/vacancy/74923706?from=vacancy_search_list&query=python',
#   'source': 'hh.ru'},
#  {'name': 'Системный администратор Linux',
#   'salary': 'от 150\u202f000 руб.',
#   'min_salary': 150000,
#   'max_salary': None,
#   'currency_salary': 'руб.',
#   'link': 'https://hh.ru/vacancy/76436539?from=vacancy_search_list&query=python',
#   'source': 'hh.ru'},
#  {'name': 'Game analyst',
#   'salary': 'З/П не указана',
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'link': 'https://hh.ru/vacancy/76637243?from=vacancy_search_list&query=python',
#   'source': 'hh.ru'},
#  {'name': 'Linux инженер',
#   'salary': 'З/П не указана',
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'link': 'https://hh.ru/vacancy/76381460?from=vacancy_search_list&query=python',
#   'source': 'hh.ru'},
#  {'name': 'Аналитик данных',
#   'salary': 'З/П не указана',
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'link': 'https://hh.ru/vacancy/73204336?from=vacancy_search_list&query=python',
#   'source': 'hh.ru'},
#  {'name': 'Разработчик в команду робототехники Маркета',
#   'salary': 'З/П не указана',
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'link': 'https://hh.ru/vacancy/70366583?from=vacancy_search_list&query=python',
#   'source': 'hh.ru'},
#  {'name': 'Data Analyst в команду Боты.KnowledgeAssistant',
#   'salary': 'З/П не указана',
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'link': 'https://hh.ru/vacancy/77358542?from=vacancy_search_list&query=python',
#   'source': 'hh.ru'},
#  {'name': 'QA engineer',
#   'salary': 'З/П не указана',
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'link': 'https://hh.ru/vacancy/77033072?from=vacancy_search_list&query=python',
#   'source': 'hh.ru'},
#  {'name': 'Cистемный администратор Linux',
#   'salary': 'З/П не указана',
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'link': 'https://hh.ru/vacancy/76486039?from=vacancy_search_list&query=python',
#   'source': 'hh.ru'},
#  {'name': 'Системный администратор/SRE',
#   'salary': '200\u202f000 – 260\u202f000 руб.',
#   'min_salary': 200000,
#   'max_salary': 260000,
#   'currency_salary': 'руб.',
#   'link': 'https://hh.ru/vacancy/77321255?from=vacancy_search_list&query=python',
#   'source': 'hh.ru'},
#  {'name': 'DeVops',
#   'salary': 'З/П не указана',
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'link': 'https://hh.ru/vacancy/75607710?from=vacancy_search_list&query=python',
#   'source': 'hh.ru'},
#  {'name': 'DWH разработчик / DWH инженер / Data Engineer',
#   'salary': 'от 110\u202f000 руб.',
#   'min_salary': 110000,
#   'max_salary': None,
#   'currency_salary': 'руб.',
#   'link': 'https://hh.ru/vacancy/76291841?from=vacancy_search_list&query=python',
#   'source': 'hh.ru'},
#  {'name': 'Администратор по управлению уязвимостями ИБ',
#   'salary': 'З/П не указана',
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'link': 'https://hh.ru/vacancy/74316773?from=vacancy_search_list&query=python',
#   'source': 'hh.ru'},
#  {'name': 'Аналитик второй линии поддержки',
#   'salary': 'от 65\u202f000 руб.',
#   'min_salary': 65000,
#   'max_salary': None,
#   'currency_salary': 'руб.',
#   'link': 'https://hh.ru/vacancy/77022274?from=vacancy_search_list&query=python',
#   'source': 'hh.ru'},
#  {'name': 'Руководитель Департамента аналитики в Практикум',
#   'salary': 'З/П не указана',
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'link': 'https://hh.ru/vacancy/76591632?from=vacancy_search_list&query=python',
#   'source': 'hh.ru'},
#  {'name': 'Network Administrator / Сетевой инженер',
#   'salary': 'З/П не указана',
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'link': 'https://hh.ru/vacancy/75901768?from=vacancy_search_list&query=python',
#   'source': 'hh.ru'},
#  {'name': 'Аналитик данных',
#   'salary': 'З/П не указана',
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'link': 'https://hh.ru/vacancy/76694853?from=vacancy_search_list&query=python',
#   'source': 'hh.ru'},
#  {'name': 'Operations Analyst',
#   'salary': 'З/П не указана',
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'link': 'https://hh.ru/vacancy/77139274?from=vacancy_search_list&query=python',
#   'source': 'hh.ru'},
#  {'name': 'Backend Разработчик: Junior Ruby on Rails + Solidity (smart contracts)',
#   'salary': 'З/П не указана',
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'link': 'https://hh.ru/vacancy/77210825?from=vacancy_search_list&query=python',
#   'source': 'hh.ru'},
#  {'name': 'Middle / Senior QA Engineer',
#   'salary': '150\u202f000 – 220\u202f000 руб.',
#   'min_salary': 150000,
#   'max_salary': 220000,
#   'currency_salary': 'руб.',
#   'link': 'https://hh.ru/vacancy/77200131?from=vacancy_search_list&query=python',
#   'source': 'hh.ru'},
#  {'name': 'Инженер системы мониторинга (направление кибербезопасность)',
#   'salary': 'от 80\u202f000 руб.',
#   'min_salary': 80000,
#   'max_salary': None,
#   'currency_salary': 'руб.',
#   'link': 'https://hh.ru/vacancy/77290818?from=vacancy_search_list&query=python',
#   'source': 'hh.ru'},
#  {'name': 'Инженер (devOps)',
#   'salary': 'З/П не указана',
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'link': 'https://hh.ru/vacancy/77068301?from=vacancy_search_list&query=python',
#   'source': 'hh.ru'},
#  {'name': 'Senior PHP Developer / PHP программист',
#   'salary': '3\u202f000 – 5\u202f000 EUR',
#   'min_salary': 3000,
#   'max_salary': 5000,
#   'currency_salary': 'EUR',
#   'link': 'https://hh.ru/vacancy/76779296?from=vacancy_search_list&query=python',
#   'source': 'hh.ru'},
#  {'name': 'Data Engineer в Практикум',
#   'salary': 'З/П не указана',
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'link': 'https://hh.ru/vacancy/77037098?from=vacancy_search_list&query=python',
#   'source': 'hh.ru'},
#  {'name': 'Системный администратор Linux',
#   'salary': 'от 70\u202f000 руб.',
#   'min_salary': 70000,
#   'max_salary': None,
#   'currency_salary': 'руб.',
#   'link': 'https://hh.ru/vacancy/75698766?from=vacancy_search_list&query=python',
#   'source': 'hh.ru'},
#  {'name': 'Системный архитектор/СТО',
#   'salary': 'от 400\u202f000 руб.',
#   'min_salary': 400000,
#   'max_salary': None,
#   'currency_salary': 'руб.',
#   'link': 'https://hh.ru/vacancy/75896764?from=vacancy_search_list&query=python',
#   'source': 'hh.ru'},
#  {'name': 'Senior Python разработчик',
#   'salary': 'З/П не указана',
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'link': 'https://hh.ru/vacancy/77206360?from=vacancy_search_list&query=python',
#   'source': 'hh.ru'},
#  {'name': 'Программист С++',
#   'salary': 'от 80\u202f000 руб.',
#   'min_salary': 80000,
#   'max_salary': None,
#   'currency_salary': 'руб.',
#   'link': 'https://hh.ru/vacancy/76848247?from=vacancy_search_list&query=python',
#   'source': 'hh.ru'},
#  {'name': 'Data scientist (проект "Антиспам")',
#   'salary': 'З/П не указана',
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'link': 'https://hh.ru/vacancy/69774675?from=vacancy_search_list&query=python',
#   'source': 'hh.ru'},
#  {'name': 'Продуктовый аналитик',
#   'salary': 'З/П не указана',
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'link': 'https://hh.ru/vacancy/76218409?from=vacancy_search_list&query=python',
#   'source': 'hh.ru'},
#  {'name': 'Senior DevOps',
#   'salary': 'до 400\u202f000 руб.',
#   'min_salary': None,
#   'max_salary': 400000,
#   'currency_salary': 'руб.',
#   'link': 'https://hh.ru/vacancy/77014448?from=vacancy_search_list&query=python',
#   'source': 'hh.ru'},
#  {'name': 'CI Engineer',
#   'salary': 'от 5\u202f000 USD',
#   'min_salary': 5000,
#   'max_salary': None,
#   'currency_salary': 'USD',
#   'link': 'https://hh.ru/vacancy/76770084?from=vacancy_search_list&query=python',
#   'source': 'hh.ru'},
#  {'name': 'Инженер сопровождения и автоматизации',
#   'salary': 'З/П не указана',
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'link': 'https://hh.ru/vacancy/77145937?from=vacancy_search_list&query=python',
#   'source': 'hh.ru'},
#  {'name': 'DBA PostgreSQL/Администратор баз данных',
#   'salary': 'З/П не указана',
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'link': 'https://hh.ru/vacancy/66987957?from=vacancy_search_list&query=python',
#   'source': 'hh.ru'},
#  {'name': 'Fraud Activity Analyst',
#   'salary': 'З/П не указана',
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'link': 'https://hh.ru/vacancy/76704863?from=vacancy_search_list&query=python',
#   'source': 'hh.ru'},
#  {'name': 'QA Engineer (Junior)',
#   'salary': 'З/П не указана',
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'link': 'https://hh.ru/vacancy/76590365?from=vacancy_search_list&query=python',
#   'source': 'hh.ru'},
#  {'name': 'Аналитик в группу аналитики рынка',
#   'salary': 'З/П не указана',
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'link': 'https://hh.ru/vacancy/76829091?from=vacancy_search_list&query=python',
#   'source': 'hh.ru'},
#  {'name': 'Разработчик fullstack',
#   'salary': '40\u202f000 – 80\u202f000 руб.',
#   'min_salary': 40000,
#   'max_salary': 80000,
#   'currency_salary': 'руб.',
#   'link': 'https://hh.ru/vacancy/76984981?from=vacancy_search_list&query=python',
#   'source': 'hh.ru'},
#  {'name': 'Системный программист / разработчик С/C++ (LINUX)',
#   'salary': 'от 80\u202f000 руб.',
#   'min_salary': 80000,
#   'max_salary': None,
#   'currency_salary': 'руб.',
#   'link': 'https://hh.ru/vacancy/77092805?from=vacancy_search_list&query=python',
#   'source': 'hh.ru'},
#  {'name': 'Инженер внедрения программного обеспечения',
#   'salary': 'до 170\u202f000 руб.',
#   'min_salary': None,
#   'max_salary': 170000,
#   'currency_salary': 'руб.',
#   'link': 'https://hh.ru/vacancy/75556406?from=vacancy_search_list&query=python',
#   'source': 'hh.ru'},
#  {'name': 'C++ Разработчик в Браузер',
#   'salary': 'З/П не указана',
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'link': 'https://hh.ru/vacancy/76204817?from=vacancy_search_list&query=python',
#   'source': 'hh.ru'},
#  {'name': 'Руководитель группы/лаборатории Reinforcement Learning',
#   'salary': 'от 200\u202f000 руб.',
#   'min_salary': 200000,
#   'max_salary': None,
#   'currency_salary': 'руб.',
#   'link': 'https://hh.ru/vacancy/76949717?from=vacancy_search_list&query=python',
#   'source': 'hh.ru'},
#  {'name': 'Преподаватель по программированию',
#   'salary': '20\u202f000 – 70\u202f000 руб.',
#   'min_salary': 20000,
#   'max_salary': 70000,
#   'currency_salary': 'руб.',
#   'link': 'https://hh.ru/vacancy/76844666?from=vacancy_search_list&query=python',
#   'source': 'hh.ru'},
#  {'name': 'Lead data scientist (Анализ цены и Trade in)',
#   'salary': 'З/П не указана',
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'link': 'https://hh.ru/vacancy/76954383?from=vacancy_search_list&query=python',
#   'source': 'hh.ru'},
#  {'name': 'Системный администратор СУБД (Junior)',
#   'salary': 'З/П не указана',
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'link': 'https://hh.ru/vacancy/77303268?from=vacancy_search_list&query=python',
#   'source': 'hh.ru'},
#  {'name': 'Реверс-инженер',
#   'salary': '100\u202f000 – 160\u202f000 руб.',
#   'min_salary': 100000,
#   'max_salary': 160000,
#   'currency_salary': 'руб.',
#   'link': 'https://hh.ru/vacancy/54462736?from=vacancy_search_list&query=python',
#   'source': 'hh.ru'},
#  {'name': 'Tools Programmer C++ (Мир танков)',
#   'salary': 'З/П не указана',
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'link': 'https://hh.ru/vacancy/77120762?from=vacancy_search_list&query=python',
#   'source': 'hh.ru'},
#  {'name': 'Build Engineer (Tanks Blitz)',
#   'salary': 'З/П не указана',
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'link': 'https://hh.ru/vacancy/72433986?from=vacancy_search_list&query=python',
#   'source': 'hh.ru'},
#  {'name': 'Продуктовый аналитик в Едадил',
#   'salary': 'З/П не указана',
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'link': 'https://hh.ru/vacancy/77026097?from=vacancy_search_list&query=python',
#   'source': 'hh.ru'}]

# %%
len(vacancy_list)
# Out:
# 780
